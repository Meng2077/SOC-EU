# %%
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
from eumap.misc import find_files, nan_percentile, GoogleSheet, ttprint

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV, GroupKFold
import joblib

from sklearn.metrics import r2_score, mean_squared_error
from tool_kit import calc_ccc, accuracy_plot, uncertainty_plot
from sklearn.model_selection import train_test_split, cross_val_score, HalvingGridSearchCV, KFold, GroupKFold

import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# # model parameters
# import json
# with open('/mnt/inca/soc_eu_model/data/006_params_annual.json', 'r') as file:
#     params = json.load(file)

# train
folder = '/mnt/inca/soc_eu_model'
df = pd.read_csv(f'{folder}/data_history/005.0_train.pnts_soc.csv',low_memory=False)
# target
train = df.loc[df['oc'].notna()]
train = train.loc[train['oc']>5]
train = train.loc[train['ref']!='nl.bis'] # show weird patterns
train.loc[:,'oc_log1p'] = np.log1p(train['oc'])
tgt = 'oc_log1p'

# test
dff = pd.read_csv(f'{folder}/data_history/004.0_validate.pnts_soc.csv',low_memory=False)
# target
test = dff.loc[dff['oc'].notna()]
test = test.loc[test['oc']>5]
test = test.loc[test['ref']!='nl.bis'] # data from nl.bis show weird patterns
test.loc[:,'oc_log1p'] = np.log1p(test['oc'])

# covariates
with open(f'{folder}/SOC-EU/features/002_selected.covar_rank.freq.txt', 'r') as file:
    lines = file.readlines()
covs = [line.strip() for line in lines]
train = train.dropna(subset=covs,how='any')
test = test.dropna(subset=covs,how='any')

spatial_cv_column = 'tile_id'
cv = GroupKFold(n_splits=5)
# Out:
# /home/opengeohub/.local/lib/python3.8/site-packages/geopandas/_compat.py:124: UserWarning: The Shapely GEOS version (3.11.3-CAPI-1.17.3) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# ### Parameter fine tuning

# %%
param_grid = {
    'n_estimators': [200, 500, 800, 1000],
    'max_depth': [10, 20, 30],
    'max_features': [0.3, 0.5, 0.7, 'log2', 'sqrt'],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

tune_rf = HalvingGridSearchCV(
    estimator=RandomForestRegressor(),
    param_grid=param_grid,
    scoring='neg_mean_squared_error',
    n_jobs=90, 
    cv=cv,
    verbose=1
)

ttprint(f'start parameter fine tuning for rf, training size: {len(train)}')
tune_rf.fit(train[covs], train[tgt], groups=train[spatial_cv_column])
ttprint("Finish fine tuning\nBest parameters found: ", tune_rf.best_params_)
joblib.dump(tune_rf.best_params_, f'{folder}/SOC-EU/model/001_best.params_rf.joblib')
joblib.dump(tune_rf.best_estimator_, f'{folder}/SOC-EU/model/002_model_rf.joblib')
# Out:
# [08:47:45] start parameter fine tuning for rf, training size: 129109
# n_iterations: 5
# n_required_iterations: 6
# n_possible_iterations: 5
# min_resources_: 531
# max_resources_: 129109
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 540
# n_resources: 531
# Fitting 5 folds for each of 540 candidates, totalling 2700 fits
# ----------
# iter: 1
# n_candidates: 180
# n_resources: 1593
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# ----------
# iter: 2
# n_candidates: 60
# n_resources: 4779
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# ----------
# iter: 3
# n_candidates: 20
# n_resources: 14337
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# ----------
# iter: 4
# n_candidates: 7
# n_resources: 43011
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [11:22:14] Finish fine tuning
# Best parameters found:  {'max_depth': 30, 'max_features': 0.3, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 800}
# ['/mnt/inca/soc_eu_model/SOC-EU/model/002_model_rf.joblib']

# %% [markdown]
# ### quantile RF

# %%
# when passing by the paramter quantiles = "mean" and aggregate_leaves_first = False, this QRF could recover the prediction of normal RF
# i.e. the "forest" is the same
# to save time, we train QRF and RF separately, since it takes forever to use QRF to do normal RF predictions
# ref: https://zillow.github.io/quantile-forest/user_guide/fit_predict.html#random-forest-predictions

from quantile_forest import RandomForestQuantileRegressor

params = joblib.load(f'{folder}/SOC-EU/model/001_best.params_rf.joblib')

ttprint('start fitting model')
qrf = RandomForestQuantileRegressor(**params, random_state=0, n_jobs=80)
qrf.fit(train[covs], train[tgt])
ttprint('end fitting model')

import numpy as np
# Calculate the lower and upper quantile values on the test data.
y_pred_interval = qrf.predict(test_set[covs], quantiles=[0.05,0.95])
y_pred_low = y_pred_interval[:, 0]
y_pred_upp = y_pred_interval[:, 1]
y_pis = np.stack([y_pred_low, y_pred_upp], axis=1)

# Calculate the point predictions on the test data.
y_pred = qrf.predict(test_set[covs], quantiles="mean", aggregate_leaves_first=False)

# %% [markdown]
# ### test

# %%
import joblib
from mapie.metrics import regression_coverage_score
from tool_kit import calc_ccc, accuracy_plot
from mapie.regression import MapieQuantileRegressor, MapieRegressor

model_params = joblib.load(f'{folder}/SOC-EU/model/001_best.params_rf.joblib')
train_t = train

# %%
title = 'qa_higher_than_5'
model = RandomForestRegressor(**model_params, n_jobs=80)
    
ttprint('start fitting model')
model.fit(train_t[covs],train_t[tgt])
ttprint('finish fitting model')
        
# joblib.dump(model, f'{folder}/SOC-EU/model/test_rf_{title}.joblib')

y_pred = model.predict(test[covs])

accuracy_plot(test[tgt], y_pred, title_text=f'rf - {title}')

y_true = test[tgt]
# y_pred = expm1(y_pred)
# y_true = expm1(y_true)

ccc = calc_ccc(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
r2 = r2_score(y_true, y_pred)
print(f"Concordance Correlation Coefficient (CCC): {ccc:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (R2): {r2:.4f}")
# Out:
# [11:29:24] start fitting model
# [11:30:43] finish fitting model
# Concordance Correlation Coefficient (CCC): 0.6847
# Root Mean Squared Error (RMSE): 0.6057
# R-squared (R2): 0.5297

# %%
def sorted_plot(y_true,y_pred,title):
    ccc = calc_ccc(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    r2 = r2_score(y_true, y_pred)
    
    # Sort values for a cleaner plot
    sorted_indices = np.argsort(y_true) # sort according to true y values, get the sorted index
    sorted_y_true = np.array(y_true)[sorted_indices] # sort with the index
    sorted_y_pred = y_pred[sorted_indices]
    
    plt.figure(figsize=(12, 6))
    plt.plot(range(len(sorted_y_true)), sorted_y_pred, 'r-', label='Predicted Values')
    plt.plot(range(len(sorted_y_true)), sorted_y_true, 'k-', label='True Values', alpha=0.7)
    
    plt.title(title)
    plt.xlabel('Data Points (sorted by true values)')
    plt.ylabel('Predicted/True Values')
    plt.legend()
    plt.show()

# %%
threshold_lower = 2.5
threshold_upper = 5
extreme_values = train_t[(train_t[tgt] > threshold_upper) | (train_t[tgt] < threshold_lower)]
print(f'extreme values size: {len(extreme_values)}')
oversample_factor = 5 # Duplicate extreme values (e.g., 5 times)
for _ in range(oversample_factor):
    train_t = pd.concat([train_t, extreme_values], ignore_index=True)

#### oversampling
title = 'oversamplling the extreme values by {} times'
model = RandomForestRegressor(**model_params, n_jobs=80)
    
ttprint('start fitting model')
model.fit(train_t[covs],train_t[tgt])
ttprint('finish fitting model')
        
# joblib.dump(model, f'{folder}/SOC-EU/model/test_rf_{title}.joblib')

y_pred = model.predict(test[covs])


y_true = test[tgt]
# y_pred = expm1(y_pred)
# y_true = expm1(y_true)

ccc = calc_ccc(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
r2 = r2_score(y_true, y_pred)
print(f"Concordance Correlation Coefficient (CCC): {ccc:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (R2): {r2:.4f}")
# Out:
# [11:47:05] start fitting model
# [11:50:07] finish fitting model
# Concordance Correlation Coefficient (CCC): 0.7111
# Root Mean Squared Error (RMSE): 0.6071
# R-squared (R2): 0.5277

# %%
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

ttprint('start fitting mapie')
# group_kfold = GroupKFold(n_splits=5)
# group_kfold.split(train_t, train[spatial_cv_column]
mapie = MapieRegressor(model, method="minmax", cv=5) # this cv is to compute the conformal scores
mapie.fit(train_t[covs], train_t[tgt],groups=train_t[spatial_cv_column])
ttprint('finish fitting mapie')

# joblib.dump(mapie, f'{folder}/SOC-EU/model/test_rf.mapie_{title}.joblib')

y_pred, y_pis = mapie.predict(test[covs], alpha=0.1) # 90% prediction interval 
# y_pis = expm1(y_pis)

title = 'cv-minmax'
uncertainty_plot(y_true, y_pred, y_pis[:, 0, 0], y_pis[:, 1, 0],title=title)

picp = np.mean((y_true >= y_pis[:, 0, 0]) & (y_true <= y_pis[:, 1, 0]))
pi_width = np.mean(y_pis[:, 1, 0] - y_pis[:, 0, 0])

print(f"Prediction Interval Coverage Probability (PICP): {picp:.4f}")
print(f"Prediction Interval Width (PI Width): {pi_width:.4f}")
# Out:
# [11:30:44] start fitting mapie
# [11:37:32] finish fitting mapie
# Prediction Interval Coverage Probability (PICP): 0.8790
# Prediction Interval Width (PI Width): 1.7223

# %%
print(len(train))
print(len(test))
# Out:
# 129109
# 4406

# %%
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

ttprint('start fitting mapie')
mapie = MapieRegressor(model, method="plus", cv=5) # this cv is to compute the conformal scores
mapie.fit(train_t[covs], train_t[tgt],groups=train_t[spatial_cv_column])
ttprint('finish fitting mapie')

# joblib.dump(mapie, f'{folder}/SOC-EU/model/test_rf.mapie_{title}.joblib')

y_pred, y_pis = mapie.predict(test[covs], alpha=0.1) # 90% prediction interval 
# y_pis = expm1(y_pis)

title = 'cv-plus'
uncertainty_plot(y_true, y_pred, y_pis[:, 0, 0], y_pis[:, 1, 0],title='cv-minmax')

picp = np.mean((y_true >= y_pis[:, 0, 0]) & (y_true <= y_pis[:, 1, 0]))
pi_width = np.mean(y_pis[:, 1, 0] - y_pis[:, 0, 0])

print(f"Prediction Interval Coverage Probability (PICP): {picp:.4f}")
print(f"Prediction Interval Width (PI Width): {pi_width:.4f}")
# Out:
# [11:37:36] start fitting mapie
# [11:44:10] finish fitting mapie
# Prediction Interval Coverage Probability (PICP): 0.8659
# Prediction Interval Width (PI Width): 1.6483

# %%
uncertainty_plot(y_true, y_pred, y_pis[:, 0, 0], y_pis[:, 1, 0],title='cv-plue')
