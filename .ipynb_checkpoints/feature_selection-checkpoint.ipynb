# %%
import numpy as np
import matplotlib.pyplot as plt
import multiprocess as mp
import glob
import time
from tqdm import tqdm
import os
import sys
import pandas as pd
from eumap.misc import find_files
from eumap.raster import read_rasters, save_rasters
from eumap.mapper import SpaceOverlay
import geopandas as gpd
from pathlib import Path
import rasterio
import pyproj
from shapely.geometry import Point
from eumap.mapper import LandMapper

import warnings

import matplotlib
import matplotlib.pyplot as plt

from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import train_test_split, cross_val_score, HalvingGridSearchCV, KFold, GroupKFold
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.feature_selection import RFECV, RFE
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, StackingRegressor
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import StackingRegressor

import joblib
import pickle

# %%
df = pd.read_csv('/mnt/landmark/soc_eu_map/training_points_v3.1_covar.csv',low_memory=False)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
print(len(df))
df = df.drop(df.loc[df['oc']=='<6'].index) # 231
print(len(df))
df = df.drop(df.loc[df['oc']=='< LOD'].index)  # 33, lucas 2018
print(len(df))
df = df.drop(df.loc[df['oc']=='<0.0'].index)  # 2, lucas 2018
print(len(df))
df['oc'] = pd.to_numeric(df['oc'], errors='coerce')
df = df.drop(df.loc[df['oc']<0].index)
print(len(df))
# Out:
# 125963
# 125732
# 125699
# 125697
# 125682

# %%
feat_cols = df.columns.values.tolist()
rm_list = ['ph_h2o','ph_ca','gps_lat','gps_long','time','ref','ph_kcl','country','oc']
for i in rm_list:
    feat_cols.remove(i)
    
tgt_col = ['oc']
dff = df[tgt_col+feat_cols+['country','gps_lat','gps_long']]

rm_list = dff.columns[dff.isna().sum()>500].values.tolist()
for i in ['oc','hzn_bottom']:
    rm_list.remove(i)
    
dff = dff.drop(columns=rm_list)
for i in rm_list:
    feat_cols.remove(i)
    

dff['oc_log'] = np.log1p(dff['oc'].values)
a = len(dff.loc[dff['oc_log'].isna()])
print(f'{a} with nan OC values')
dff = dff.dropna(how='any')
dff = dff.reset_index(drop=True)
print(f'original feature numbers: {len(feat_cols)}')
print(f'{len(dff)} left after dropna')

tgt_col = ['oc_log']
# Out:
# 2088 with nan OC values
# original feature numbers: 782
# 121437 left after dropna

# %%
grouped = dff.groupby('country').size().reset_index(name='Count').sort_values(by='Count',ascending=False)
group = grouped.loc[grouped['Count']>3000]['country'].values.tolist()

dff['group_id'] = dff.apply(lambda x: x['country']+'_'+str(int(x['gps_long']*4))+','+str(int(x['gps_lat']*4)) if x['country'] in group else x['country'],axis=1)
# grouped = dff.groupby('coor_index').size().reset_index(name='Count').sort_values(by='Count',ascending=False)
# grouped.head(20)
groupt = dff.groupby('group_id').size().reset_index(name='Count').sort_values(by='Count',ascending=False)
groupt.head(20)
# Out:
#             group_id  Count
# 4455        RO-lucas   2857
# 5457  belgium_16,204   2198
# 5433        UK-lucas   2147
# 6418        scotland   2125
# 5441  belgium_12,204   2114
# 5453  belgium_15,204   1792
# 5438  belgium_11,204   1781
# 710         EL-lucas   1731
# 2           BG-lucas   1723
# 5456  belgium_16,203   1669
# 5467  belgium_19,203   1648
# 5445  belgium_13,204   1597
# 5460  belgium_17,203   1537
# 5437  belgium_11,203   1517
# 4454        PT-lucas   1491
# 5440  belgium_12,203   1433
# 0           AT-lucas   1414
# 5461  belgium_17,204   1317
# 4           CZ-lucas   1316
# 3276        HU-lucas   1263

# %%
# x_slc, x_test, y_slc, y_test = train_test_split(dff[feat_cols], dff[tgt_col], test_size=0.6, random_state=1)
df_slc, df_test = train_test_split(dff, test_size=0.7, random_state=42)

cv, groups = GroupKFold(5), df_slc['group_id']

names = ['score_mean','score_std','optimal_feature_number','feature_importance']
dfe = pd.DataFrame(columns=names)

# %%
grid_score_mean = []
grid_score_std = []
opti_feat_num = []
grid_feat_import = []
grid_feat = []

warnings.filterwarnings('ignore')
for i in [0,1,2,3,4]:
    rfecv = RFECV(estimator=RandomForestRegressor(200, n_jobs=60, random_state=i), cv=cv, step=10, 
                  min_features_to_select=30, n_jobs=1, scoring='neg_mean_squared_error', verbose=1)
    rfecv.fit(df_slc[feat_cols], df_slc[tgt_col].values, groups=groups)
    
    grid_score_mean += [rfecv.cv_results_['mean_test_score']]
    grid_score_std += [rfecv.cv_results_["std_test_score"]]
    opti_feat_num.append(rfecv.n_features_)
    grid_feat_import.append(rfecv.estimator_.feature_importances_)
    
    dfe.loc[len(dfe)]=[rfecv.cv_results_['mean_test_score'],rfecv.cv_results_["std_test_score"],rfecv.n_features_,rfecv.estimator_.feature_importances_]
    dfe.to_csv('/mnt/inca/soc_eu_model/feature_selection/evaluation_matrix_log.csv')
    
    selected_feature_indices = np.where(rfecv.support_)[0]
    selected_features = [feat_cols[i] for i in selected_feature_indices]
    grid_feat.append(selected_features)
    print(f'round {i} finished')
# Out:
# Fitting estimator with 782 features.
# Fitting estimator with 772 features.
# Fitting estimator with 762 features.
# Fitting estimator with 752 features.
# Fitting estimator with 742 features.
# Fitting estimator with 732 features.
# Fitting estimator with 722 features.
# Fitting estimator with 712 features.
# Fitting estimator with 702 features.
# Fitting estimator with 692 features.
# Fitting estimator with 682 features.
# Fitting estimator with 672 features.
# Fitting estimator with 662 features.
# Fitting estimator with 652 features.
# Fitting estimator with 642 features.
# Fitting estimator with 632 features.
# Fitting estimator with 622 features.
# Fitting estimator with 612 features.
# Fitting estimator with 602 features.
# Fitting estimator with 592 features.
# Fitting estimator with 582 features.
# Fitting estimator with 572 features.
# Fitting estimator with 562 features.
# Fitting estimator with 552 features.
# Fitting estimator with 542 features.
# Fitting estimator with 532 features.
# Fitting estimator with 522 features.
# Fitting estimator with 512 features.
# Fitting estimator with 502 features.
# Fitting estimator with 492 features.
# Fitting estimator with 482 features.
# Fitting estimator with 472 features.
# Fitting estimator with 462 features.
# Fitting estimator with 452 features.
# Fitting estimator with 442 features.
# Fitting estimator with 432 features.
# Fitting estimator with 422 features.
# Fitting estimator with 412 features.
# Fitting estimator with 402 features.
# Fitting estimator with 392 features.
# Fitting estimator with 382 features.
# Fitting estimator with 372 features.
# Fitting estimator with 362 features.
# Fitting estimator with 352 features.
# Fitting estimator with 342 features.
# Fitting estimator with 332 features.
# Fitting estimator with 322 features.
# Fitting estimator with 312 features.
# Fitting estimator with 302 features.
# Fitting estimator with 292 features.
# Fitting estimator with 282 features.
# Fitting estimator with 272 features.
# Fitting estimator with 262 features.
# Fitting estimator with 252 features.
# Fitting estimator with 242 features.
# Fitting estimator with 232 features.
# Fitting estimator with 222 features.
# Fitting estimator with 212 features.
# Fitting estimator with 202 features.
# Fitting estimator with 192 features.
# Fitting estimator with 182 features.
# Fitting estimator with 172 features.
# Fitting estimator with 162 features.
# Fitting estimator with 152 features.
# Fitting estimator with 142 features.
# Fitting estimator with 132 features.
# Fitting estimator with 122 features.
# Fitting estimator with 112 features.
# Fitting estimator with 102 features.
# Fitting estimator with 92 features.
# Fitting estimator with 82 features.
# Fitting estimator with 72 features.
# Fitting estimator with 62 features.
# Fitting estimator with 52 features.
# Fitting estimator with 42 features.
# Fitting estimator with 32 features.
# Fitting estimator with 782 features.
# Fitting estimator with 772 features.
# Fitting estimator with 762 features.
# Fitting estimator with 752 features.

# %%
# mean = []
# for column in dfe.columns.values.tolist():
#     temp = []
#     for index, row in dfe.iterrows():
#         temp.append(row[column])
# #     print(column,temp)
#     temp = np.array(temp)
#     mean.append(np.mean(temp,axis=0))

# %%
featn = np.arange(782,10,-20)
featn = featn[::-1]

for index, row in dfe.iterrows():
    plt.plot(featn,row['score_mean'], marker='o',label=row['trial'])
#     plt.errorbar(featn,grid_score_mean[i],grid_score_std[i],label=f'trial-{i}')
#     plt.ylim(-2.1,-1.6)
    plt.xlabel('Number of Features')
    plt.ylabel('Cross-Validation Negative Mean Squared Error')
    plt.title(f'Scree Plot')
    plt.legend()
    plt.show()

# %%
num_feat = featn[np.argmax(dfe.loc[5,'score_mean'])]

# %%
groups
# Out:
# 41123     ES-lucas
# 85826     IT-lucas
# 53857     SI-lucas
# 102232     germany
# 6343       belgium
#             ...
# 110268    LU-lucas
# 119879    BG-lucas
# 103694    ES-lucas
# 860       scotland
# 15795      belgium
# Name: country, Length: 36431, dtype: object

# %%
rfe = RFE(estimator=RandomForestRegressor(200, n_jobs=60, random_state=0), step=20, n_features_to_select=num_feat, verbose=1)
rfe.fit(df_slc[feat_cols], df_slc[tgt_col].values)
# Out:
# Fitting estimator with 782 features.
# Fitting estimator with 762 features.
# Fitting estimator with 742 features.
# Fitting estimator with 722 features.
# Fitting estimator with 702 features.
# Fitting estimator with 682 features.
# Fitting estimator with 662 features.
# Fitting estimator with 642 features.
# RFE(estimator=RandomForestRegressor(n_estimators=200, n_jobs=60,
#                                     random_state=0),
#     n_features_to_select=622, step=20, verbose=1)

# %%
result = list(np.array(feat_cols)[rfe.support_])

# %%
result
# Out:
# ['hzn_top',
#  'hzn_bottom',
#  'upslope.curvature_merit.dem_m_250m_s_20170101_20171231',
#  'slope_merit.dem_m_250m_s_20170101_20171231',
#  'dtm_surface.lithology_egdi.1m.clay_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.clasticsediment_p_250m_2018',
#  'northness_merit.dem_m_250m_s_20180101_20181231',
#  'easthness_merit.dem_m_250m_s_20180101_20181231',
#  'downlslope.curvature_merit.dem_m_250m_s_20170101_20171231',
#  'dtm_surface.lithology_egdi.1m.peat_p_250m_2018',
#  'elevation_aw3d30.dsm_m_30m_s_20180101_20181231',
#  'elev.lowestmode_gedi.eml_mf_30m_s_20000101_20181231',
#  'slope.pct_copernicus.glo.fabdem.dtm_m_30m_s_20100101_20151231',
#  'evi_mod13q1.v061.trend.logit.ols.alpha_pv_250m_s_20000101_20211231',
#  'evi_mod13q1.m08.log_p75_250m_s_20000101_20211231',
#  'evi_mod13q1.m04.log_p25_250m_s_20000101_20211231',
#  'evi_mod13q1.m06.log_p75_250m_s_20000101_20211231',
#  'evi_mod13q1.m06.log_p50_250m_s_20000101_20211231',
#  'evi_mod13q1.m04.log_p75_250m_s_20000101_20211231',
#  'evi_mod13q1.m08.log_p25_250m_s_20000101_20211231',
#  'evi_mod13q1.m09.log_p25_250m_s_20000101_20211231',
#  'evi_mod13q1.m10.log_p25_250m_s_20000101_20211231',
#  'evi_mod13q1.m07.log_p75_250m_s_20000101_20211231',
#  'evi_mod13q1.m11.log_p25_250m_s_20000101_20211231',
#  'evi_mod13q1.m09.log_p50_250m_s_20000101_20211231',
#  'evi_mod13q1.m11.log_p50_250m_s_20000101_20211231',
#  'evi_mod13q1.m11.log_p75_250m_s_20000101_20211231',
#  'evi_mod13q1.m06.log_p25_250m_s_20000101_20211231',
#  'evi_mod13q1.m10.log_p50_250m_s_20000101_20211231',
#  'evi_mod13q1.m10.log_p75_250m_s_20000101_20211231',
#  'evi_mod13q1.m07.log_p50_250m_s_20000101_20211231',
#  'evi_mod13q1.m05.log_p50_250m_s_20000101_20211231',
#  'evi_mod13q1.m07.log_p25_250m_s_20000101_20211231',
#  'evi_mod13q1.m05.log_p25_250m_s_20000101_20211231',
#  'evi_mod13q1.m05.log_p75_250m_s_20000101_20211231',
#  'evi_mod13q1.m09.log_p75_250m_s_20000101_20211231',
#  'evi_mod13q1.m04.log_p50_250m_s_20000101_20211231',
#  'evi_mod13q1.v061.trend.logit.ols.alpha_sd_250m_s_20000101_20211231',
#  'evi_mod13q1.m08.log_p50_250m_s_20000101_20211231',
#  'evi_mod13q1.v061.trend.logit.ols.beta_sd_250m_s_20000101_20211231',
#  'evi_mod13q1.v061_p95_250m_s_{year}0101_{year}1231',
#  'evi_mod13q1.v061.trend.logit.ols.alpha_m_250m_s_20000101_20211231',
#  'evi_mod13q1.v061.trend.logit.ols.beta_pv_250m_s_20000101_20211231',
#  'evi_mod13q1.v061.trend.logit.ols.beta_l.025_250m_s_20000101_20211231',
#  'evi_mod13q1.v061_sd_250m_s_{year}0101_{year}1231',
#  'evi_mod13q1.v061_p05_250m_s_{year}0101_{year}1231',
#  'evi_mod13q1.v061_p50_250m_s_{year}0101_{year}1231',
#  'evi_mod13q1.v061.trend.logit.ols.alpha_tv_250m_s_20000101_20211231',
#  'evi_mod13q1.v061.trend.logit.ols.beta_u.975_250m_s_20000101_20211231',
#  'evi_mod13q1.v061.trend.logit.ols_r2_250m_s_20000101_20211231',
#  'evi_mod13q1.v061.trend.logit.ols.beta_tv_250m_s_20000101_20211231',
#  'ndvi_mod13q1.v061_sd_250m_s_{year}0201_{year}0228',
#  'evi_mod13q1.tmwm.inpaint_p90_250m_s_{year}0101_{year}0228',
#  'evi_mod13q1.v061.trend.logit.ols.beta_m_250m_s_20000101_20211231',
#  'ndvi_mod13q1.v061_sd_250m_s_{year}0101_{year}0131',
#  'ndvi_mod13q1.v061_sd_250m_s_{year}0801_{year}0831',
#  'ndvi_mod13q1.v061_sd_250m_s_{year}0901_{year}0930',
#  'evi_mod13q1.tmwm.inpaint_p90_250m_s_{year}1101_{year}1231',
#  'evi_mod13q1.tmwm.inpaint_p90_250m_s_{year}0301_{year}0430',
#  'evi_mod13q1.tmwm.inpaint_p90_250m_s_{year}0901_{year}1031',
#  'evi_mod13q1.stl.trend_p90_250m_s_{year}0901_{year}1031',
#  'ndvi_mod13q1.v061_sd_250m_s_{year}1001_{year}1031',
#  'evi_mod13q1.tmwm.inpaint_p90_250m_s_{year}0701_{year}0831',
#  'ndvi_mod13q1.v061_p50_250m_s_{year}0201_{year}0228',
#  'evi_mod13q1.tmwm.inpaint_p90_250m_s_{year}0501_{year}0630',
#  'ndvi_mod13q1.v061_sd_250m_s_{year}0501_{year}0531',
#  'evi_mod13q1.stl.trend_p90_250m_s_{year}0701_{year}0831',
#  'ndvi_mod13q1.v061_sd_250m_s_{year}0301_{year}0331',
#  'evi_mod13q1.stl.trend_p90_250m_s_{year}0301_{year}0430',
#  'ndvi_mod13q1.v061_sd_250m_s_{year}0401_{year}0430',
#  'ndvi_mod13q1.v061_p50_250m_s_{year}0101_{year}0131',
#  'evi_mod13q1.stl.trend_p90_250m_s_{year}0101_{year}0228',
#  'ndvi_mod13q1.v061_sd_250m_s_{year}0601_{year}0630',
#  'ndvi_mod13q1.v061_p50_250m_s_{year}0401_{year}0430',
#  'ndvi_mod13q1.v061_p50_250m_s_{year}0701_{year}0731',
#  'ndvi_mod13q1.v061_p50_250m_s_{year}0301_{year}0331',
#  'evi_mod13q1.stl.trend_p90_250m_s_{year}1101_{year}1231',
#  'ndvi_mod13q1.v061_p50_250m_s_{year}0801_{year}0831',
#  'ndvi_mod13q1.v061_p50_250m_s_{year}0901_{year}0930',
#  'ndvi_mod13q1.v061_p50_250m_s_{year}0601_{year}0630',
#  'ndvi_mod13q1.v061_p50_250m_s_{year}1001_{year}1031',
#  'ndvi_mod13q1.v061_sd_250m_s_{year}0701_{year}0731',
#  'ndvi_mod13q1.v061_p50_250m_s_{year}0501_{year}0531',
#  'ndvi_mod13q1.v061_p50_250m_s_{year}1201_{year}1231',
#  'evi_mod13q1.stl.trend_p90_250m_s_{year}0501_{year}0630',
#  'ndvi_mod13q1.v061_p50_250m_s_{year}1101_{year}1130',
#  'ndvi_mod13q1.v061_sd_250m_s_{year}0101_{year}1231',
#  'ndvi_mod13q1.v061_p95_250m_s_{year}0101_{year}1231',
#  'ndvi_mod13q1.v061_p05_250m_s_{year}0101_{year}1231',
#  'fapar_essd.lstm_p95_250m_s_{year}0301_{year}0331',
#  'ndvi_mod13q1.v061_sd_250m_s_{year}1201_{year}1231',
#  'fapar_essd.lstm_p05_250m_s_{year}0401_{year}0430',
#  'fapar_essd.lstm_p05_250m_s_{year}0701_{year}0731',
#  'ndvi_mod13q1.v061.trend_p50_250m_s_{year}0301_{year}0331',
#  'fapar_essd.lstm_p95_250m_s_{year}0401_{year}0430',
#  'fapar_essd.lstm_p05_250m_s_{year}0501_{year}0531',
#  'fapar_essd.lstm_p95_250m_s_{year}0901_{year}0930',
#  'fapar_essd.lstm_p95_250m_s_{year}1101_{year}1130',
#  'fapar_essd.lstm_p50_250m_s_{year}0301_{year}0331',
#  'fapar_essd.lstm_p05_250m_s_{year}0301_{year}0331',
#  'fapar_essd.lstm_p50_250m_s_{year}0601_{year}0630',
#  'ndvi_mod13q1.v061.trend_p50_250m_s_{year}0601_{year}0630',
#  'ndvi_mod13q1.v061.trend_p50_250m_s_{year}0201_{year}0228',
#  'ndvi_mod13q1.v061.trend_p50_250m_s_{year}0101_{year}0131',
#  'fapar_essd.lstm_p95_250m_s_{year}0501_{year}0531',
#  'fapar_essd.lstm_p50_250m_s_{year}0701_{year}0731',
#  'fapar_essd.lstm_p95_250m_s_{year}0601_{year}0630',
#  'fapar_essd.lstm_p95_250m_s_{year}0701_{year}0731',
#  'fapar_essd.lstm_p50_250m_s_{year}0401_{year}0430',
#  'fapar_essd.lstm_p05_250m_s_{year}0901_{year}0930',
#  'ndvi_mod13q1.v061_sd_250m_s_{year}1101_{year}1130',
#  'fapar_essd.lstm_p05_250m_s_{year}0801_{year}0831',
#  'fapar_essd.lstm_p05_250m_s_{year}1101_{year}1130',
#  'fapar_essd.lstm_p50_250m_s_{year}0901_{year}0930',
#  'fapar_essd.lstm_p50_250m_s_{year}0501_{year}0531',
#  'fapar_essd.lstm_p05_250m_s_{year}1001_{year}1031',
#  'fapar_essd.lstm_p05_250m_s_{year}1201_{year}1231',
#  'fapar_essd.lstm_p50_250m_s_{year}1001_{year}1031',
#  'fapar_essd.lstm_p95_250m_s_{year}1201_{year}1231',
#  'fapar_essd.lstm_p95_250m_s_{year}1001_{year}1031',
#  'fapar_essd.lstm_p50_250m_s_{year}0801_{year}0831',
#  'fapar_essd.lstm_p50_250m_s_{year}1201_{year}1231',
#  'fapar_essd.lstm_p05_250m_s_{year}0601_{year}0630',
#  'fapar_essd.lstm_p50_250m_s_{year}1101_{year}1130',
#  'fapar_essd.lstm_p95_250m_s_{year}0801_{year}0831',
#  'ndvi_mod13q1.v061_p50_250m_s_{year}0101_{year}1231',
#  'ndvi_mod13q1.v061.trend_p50_250m_s_{year}1101_{year}1130',
#  'ndvi_mod13q1.v061.trend_p50_250m_s_{year}1201_{year}1231',
#  'blue_mod13q1.v061_sd_250m_s_{year}0201_{year}0228',
#  'blue_mod13q1.v061_sd_250m_s_{year}0401_{year}0430',
#  'blue_mod13q1.v061_sd_250m_s_{year}0701_{year}0731',
#  'blue_mod13q1.v061_sd_250m_s_{year}0801_{year}0831',
#  'blue_mod13q1.v061_sd_250m_s_{year}0301_{year}0331',
#  'blue_mod13q1.v061_sd_250m_s_{year}0601_{year}0630',
#  'blue_mod13q1.v061_sd_250m_s_{year}0101_{year}0131',
#  'blue_mod13q1.v061_sd_250m_s_{year}1101_{year}1130',
#  'blue_mod13q1.v061_sd_250m_s_{year}0901_{year}0930',
#  'blue_mod13q1.v061_sd_250m_s_{year}0501_{year}0531',
#  'blue_mod13q1.v061_p50_250m_s_{year}0301_{year}0331',
#  'blue_mod13q1.v061_p50_250m_s_{year}0701_{year}0731',
#  'blue_mod13q1.v061_sd_250m_s_{year}1001_{year}1031',
#  'blue_mod13q1.v061_sd_250m_s_{year}0101_{year}1231',
#  'blue_mod13q1.v061_p50_250m_s_{year}0201_{year}0228',
#  'blue_mod13q1.v061_sd_250m_s_{year}1201_{year}1231',
#  'blue_mod13q1.v061_p50_250m_s_{year}0401_{year}0430',
#  'red_mod13q1.v061_sd_250m_s_{year}0201_{year}0228',
#  'blue_mod13q1.v061_p50_250m_s_{year}0901_{year}0930',
#  'red_mod13q1.v061_sd_250m_s_{year}1101_{year}1130',
#  'red_mod13q1.v061_sd_250m_s_{year}1001_{year}1031',
#  'red_mod13q1.v061_sd_250m_s_{year}0301_{year}0331',
#  'red_mod13q1.m04.log_p25_250m_s_20000101_20211231',
#  'red_mod13q1.m04.log_p75_250m_s_20000101_20211231',
#  'red_mod13q1.v061_sd_250m_s_{year}0501_{year}0531',
#  'blue_mod13q1.v061_p50_250m_s_{year}0101_{year}0131',
#  'red_mod13q1.v061_sd_250m_s_{year}0101_{year}0131',
#  'blue_mod13q1.v061_p50_250m_s_{year}1001_{year}1031',
#  'red_mod13q1.m04.log_p50_250m_s_20000101_20211231',
#  'blue_mod13q1.v061_p50_250m_s_{year}1201_{year}1231',
#  'blue_mod13q1.v061_p50_250m_s_{year}0101_{year}1231',
#  'blue_mod13q1.v061_p50_250m_s_{year}0801_{year}0831',
#  'blue_mod13q1.v061_p50_250m_s_{year}0601_{year}0630',
#  'red_mod13q1.v061_sd_250m_s_{year}0701_{year}0731',
#  'red_mod13q1.v061_sd_250m_s_{year}0601_{year}0630',
#  'blue_mod13q1.v061_p50_250m_s_{year}1101_{year}1130',
#  'red_mod13q1.v061_p50_250m_s_{year}0601_{year}0630',
#  'red_mod13q1.m08.log_p75_250m_s_20000101_20211231',
#  'red_mod13q1.m08.log_p50_250m_s_20000101_20211231',
#  'red_mod13q1.v061_sd_250m_s_{year}0401_{year}0430',
#  'red_mod13q1.v061_sd_250m_s_{year}0901_{year}0930',
#  'red_mod13q1.m07.log_p25_250m_s_20000101_20211231',
#  'red_mod13q1.m07.log_p75_250m_s_20000101_20211231',
#  'red_mod13q1.v061_p50_250m_s_{year}0501_{year}0531',
#  'red_mod13q1.m06.log_p75_250m_s_20000101_20211231',
#  'red_mod13q1.m08.log_p25_250m_s_20000101_20211231',
#  'red_mod13q1.m05.log_p50_250m_s_20000101_20211231',
#  'red_mod13q1.v061_p50_250m_s_{year}0201_{year}0228',
#  'red_mod13q1.m06.log_p25_250m_s_20000101_20211231',
#  'red_mod13q1.m07.log_p50_250m_s_20000101_20211231',
#  'red_mod13q1.m05.log_p25_250m_s_20000101_20211231',
#  'red_mod13q1.v061_p50_250m_s_{year}0101_{year}0131',
#  'red_mod13q1.m11.log_p25_250m_s_20000101_20211231',
#  'blue_mod13q1.v061_p50_250m_s_{year}0501_{year}0531',
#  'red_mod13q1.m11.log_p75_250m_s_20000101_20211231',
#  'red_mod13q1.m11.log_p50_250m_s_20000101_20211231',
#  'red_mod13q1.v061_p50_250m_s_{year}0301_{year}0331',
#  'red_mod13q1.m05.log_p75_250m_s_20000101_20211231',
#  'red_mod13q1.v061_p50_250m_s_{year}1101_{year}1130',
#  'red_mod13q1.m10.log_p25_250m_s_20000101_20211231',
#  'red_mod13q1.v061_p50_250m_s_{year}0801_{year}0831',
#  'red_mod13q1.m10.log_p75_250m_s_20000101_20211231',
#  'red_mod13q1.m10.log_p50_250m_s_20000101_20211231',
#  'red_mod13q1.v061_p50_250m_s_{year}1001_{year}1031',
#  'red_mod13q1.m09.log_p25_250m_s_20000101_20211231',
#  'red_mod13q1.v061_p50_250m_s_{year}0901_{year}0930',
#  'red_mod13q1.v061_p50_250m_s_{year}0701_{year}0731',
#  'red_mod13q1.m09.log_p50_250m_s_20000101_20211231',
#  'red_mod13q1.m09.log_p75_250m_s_20000101_20211231',
#  'red_mod13q1.v061_sd_250m_s_{year}1201_{year}1231',
#  'nir_mod13q1.m08.log_p50_250m_s_20000101_20211231',
#  'red_mod13q1.v061_p50_250m_s_{year}1201_{year}1231',
#  'blue_mod13q1.v061_p05_250m_s_{year}0101_{year}1231',
#  'nir_mod13q1.m04.log_p25_250m_s_20000101_20211231',
#  'nir_mod13q1.m04.log_p75_250m_s_20000101_20211231',
#  'red_mod13q1.v061_sd_250m_s_{year}0101_{year}1231',
#  'red_mod13q1.v061_p50_250m_s_{year}0101_{year}1231',
#  'blue_mod13q1.v061_p95_250m_s_{year}0101_{year}1231',
#  'red_mod13q1.v061_sd_250m_s_{year}0801_{year}0831',
#  'red_mod13q1.v061_p05_250m_s_{year}0101_{year}1231',
#  'nir_mod13q1.m07.log_p75_250m_s_20000101_20211231',
#  'red_mod13q1.v061_p95_250m_s_{year}0101_{year}1231',
#  'nir_mod13q1.m05.log_p25_250m_s_20000101_20211231',
#  'nir_mod13q1.m07.log_p25_250m_s_20000101_20211231',
#  'red_mod13q1.v061_p50_250m_s_{year}0401_{year}0430',
#  'nir_mod13q1.m05.log_p75_250m_s_20000101_20211231',
#  'nir_mod13q1.m11.log_p25_250m_s_20000101_20211231',
#  'nir_mod13q1.v061_sd_250m_s_{year}0201_{year}0228',
#  'nir_mod13q1.m10.log_p25_250m_s_20000101_20211231',
#  'nir_mod13q1.v061_sd_250m_s_{year}0101_{year}0131',
#  'nir_mod13q1.m09.log_p25_250m_s_20000101_20211231',
#  'nir_mod13q1.v061_sd_250m_s_{year}0501_{year}0531',
#  'nir_mod13q1.v061_sd_250m_s_{year}0601_{year}0630',
#  'nir_mod13q1.v061_sd_250m_s_{year}0401_{year}0430',
#  'nir_mod13q1.v061_sd_250m_s_{year}0301_{year}0331',
#  'nir_mod13q1.v061_sd_250m_s_{year}0701_{year}0731',
#  'nir_mod13q1.v061_sd_250m_s_{year}1201_{year}1231',
#  'nir_mod13q1.v061_sd_250m_s_{year}1101_{year}1130',
#  'nir_mod13q1.v061_sd_250m_s_{year}0801_{year}0831',
#  'nir_mod13q1.v061_p50_250m_s_{year}1001_{year}1031',
#  'nir_mod13q1.v061_p50_250m_s_{year}0401_{year}0430',
#  'nir_mod13q1.v061_sd_250m_s_{year}1001_{year}1031',
#  'nir_mod13q1.v061_p50_250m_s_{year}0601_{year}0630',
#  'nir_mod13q1.v061_p50_250m_s_{year}0301_{year}0331',
#  'nir_mod13q1.v061_p50_250m_s_{year}0101_{year}0131',
#  'nir_mod13q1.v061_p50_250m_s_{year}0701_{year}0731',
#  'nir_mod13q1.v061_p50_250m_s_{year}0201_{year}0228',
#  'nir_mod13q1.v061_p95_250m_s_{year}0101_{year}1231',
#  'nir_mod13q1.v061_p50_250m_s_{year}1201_{year}1231',
#  'mir_mod13q1.m04.log_p25_250m_s_20000101_20211231',
#  'mir_mod13q1.m04.log_p75_250m_s_20000101_20211231',
#  'nir_mod13q1.v061_p50_250m_s_{year}0901_{year}0930',
#  'nir_mod13q1.v061_sd_250m_s_{year}0101_{year}1231',
#  'mir_mod13q1.m08.log_p25_250m_s_20000101_20211231',
#  'nir_mod13q1.v061_p50_250m_s_{year}0801_{year}0831',
#  'nir_mod13q1.v061_p05_250m_s_{year}0101_{year}1231',
#  'nir_mod13q1.v061_p50_250m_s_{year}0501_{year}0531',
#  'nir_mod13q1.v061_p50_250m_s_{year}1101_{year}1130',
#  'mir_mod13q1.m08.log_p75_250m_s_20000101_20211231',
#  'mir_mod13q1.m04.log_p50_250m_s_20000101_20211231',
#  'mir_mod13q1.m06.log_p75_250m_s_20000101_20211231',
#  'mir_mod13q1.v061_sd_250m_s_{year}0201_{year}0228',
#  'mir_mod13q1.v061_sd_250m_s_{year}0301_{year}0331',
#  'mir_mod13q1.m07.log_p25_250m_s_20000101_20211231',
#  'mir_mod13q1.m06.log_p25_250m_s_20000101_20211231',
#  'mir_mod13q1.v061_sd_250m_s_{year}0601_{year}0630',
#  'mir_mod13q1.m06.log_p50_250m_s_20000101_20211231',
#  'mir_mod13q1.m05.log_p25_250m_s_20000101_20211231',
#  'mir_mod13q1.m11.log_p50_250m_s_20000101_20211231',
#  'mir_mod13q1.m05.log_p50_250m_s_20000101_20211231',
#  'mir_mod13q1.v061_sd_250m_s_{year}0101_{year}0131',
#  'mir_mod13q1.m05.log_p75_250m_s_20000101_20211231',
#  'mir_mod13q1.m11.log_p25_250m_s_20000101_20211231',
#  'mir_mod13q1.v061_sd_250m_s_{year}0401_{year}0430',
#  'nir_mod13q1.v061_sd_250m_s_{year}0901_{year}0930',
#  'mir_mod13q1.m10.log_p50_250m_s_20000101_20211231',
#  'mir_mod13q1.v061_sd_250m_s_{year}1001_{year}1031',
#  'mir_mod13q1.m10.log_p25_250m_s_20000101_20211231',
#  'mir_mod13q1.v061_sd_250m_s_{year}0801_{year}0831',
#  'mir_mod13q1.m10.log_p75_250m_s_20000101_20211231',
#  'mir_mod13q1.v061_p50_250m_s_{year}0201_{year}0228',
#  'mir_mod13q1.m11.log_p75_250m_s_20000101_20211231',
#  'mir_mod13q1.v061_p50_250m_s_{year}0101_{year}0131',
#  'mir_mod13q1.v061_sd_250m_s_{year}0501_{year}0531',
#  'mir_mod13q1.v061_sd_250m_s_{year}0701_{year}0731',
#  'mir_mod13q1.v061_sd_250m_s_{year}1101_{year}1130',
#  'mir_mod13q1.v061_sd_250m_s_{year}1201_{year}1231',
#  'mir_mod13q1.v061_sd_250m_s_{year}0901_{year}0930',
#  'mir_mod13q1.v061_p50_250m_s_{year}0701_{year}0731',
#  'mir_mod13q1.v061_p50_250m_s_{year}0601_{year}0630',
#  'mir_mod13q1.v061_p50_250m_s_{year}1101_{year}1130',
#  'mir_mod13q1.v061_p50_250m_s_{year}0501_{year}0531',
#  'mir_mod13q1.v061_p50_250m_s_{year}1001_{year}1031',
#  'mir_mod13q1.v061_p50_250m_s_{year}0901_{year}0930',
#  'mir_mod13q1.v061_p95_250m_s_{year}0101_{year}1231',
#  'mir_mod13q1.v061_sd_250m_s_{year}0101_{year}1231',
#  'mir_mod13q1.v061_p50_250m_s_{year}0801_{year}0831',
#  'mir_mod13q1.v061_p50_250m_s_{year}0101_{year}1231',
#  'mir_mod13q1.v061_p05_250m_s_{year}0101_{year}1231',
#  'nir_mod13q1.v061_p50_250m_s_{year}0101_{year}1231',
#  'mir_mod13q1.v061_p50_250m_s_{year}0401_{year}0430',
#  'mir_mod13q1.v061_p50_250m_s_{year}0301_{year}0331',
#  'mir_mod13q1.v061_p50_250m_s_{year}1201_{year}1231',
#  'lcv_blue_landsat.glad.ard_p75_30m_0..0cm_{year}.06.25..{year}.09.12',
#  'lcv_blue_landsat.glad.ard_p50_30m_0..0cm_{year}.06.25..{year}.09.12',
#  'lcv_blue_landsat.glad.ard_p25_30m_0..0cm_{year}.03.21..{year}.06.24',
#  'lcv_blue_landsat.glad.ard_p50_30m_0..0cm_{year}.03.21..{year}.06.24',
#  'lcv_blue_landsat.glad.ard_p75_30m_0..0cm_{year}.03.21..{year}.06.24',
#  'lcv_blue_landsat.glad.ard_p75_30m_0..0cm_{year}.09.13..{year}.12.01',
#  'lcv_blue_landsat.glad.ard_p50_30m_0..0cm_{year}.09.13..{year}.12.01',
#  'lcv_blue_landsat.glad.ard_p25_30m_0..0cm_{year}.09.13..{year}.12.01',
#  'lcv_green_landsat.glad.ard_p75_30m_0..0cm_{year}.06.25..{year}.09.12',
#  'lcv_green_landsat.glad.ard_p50_30m_0..0cm_{year}.06.25..{year}.09.12',
#  'lcv_green_landsat.glad.ard_p25_30m_0..0cm_{year}.06.25..{year}.09.12',
#  'lcv_green_landsat.glad.ard_p25_30m_0..0cm_{year}.03.21..{year}.06.24',
#  'lcv_green_landsat.glad.ard_p25_30m_0..0cm_{year}.09.13..{year}.12.01',
#  'lcv_green_landsat.glad.ard_p75_30m_0..0cm_{year}.03.21..{year}.06.24',
#  'lcv_blue_landsat.glad.ard_p25_30m_0..0cm_{year_minus_1}.12.02..{year}.03.20',
#  'lcv_green_landsat.glad.ard_p50_30m_0..0cm_{year}.09.13..{year}.12.01',
#  'lcv_green_landsat.glad.ard_p75_30m_0..0cm_{year}.09.13..{year}.12.01',
#  'lcv_blue_landsat.glad.ard_p50_30m_0..0cm_{year_minus_1}.12.02..{year}.03.20',
#  'lcv_red_landsat.glad.ard_p25_30m_0..0cm_{year}.06.25..{year}.09.12',
#  'lcv_red_landsat.glad.ard_p50_30m_0..0cm_{year}.06.25..{year}.09.12',
#  'lcv_blue_landsat.glad.ard_p75_30m_0..0cm_{year_minus_1}.12.02..{year}.03.20',
#  'lcv_green_landsat.glad.ard_p50_30m_0..0cm_{year_minus_1}.12.02..{year}.03.20',
#  'lcv_red_landsat.glad.ard_p75_30m_0..0cm_{year}.06.25..{year}.09.12',
#  'lcv_green_landsat.glad.ard_p25_30m_0..0cm_{year_minus_1}.12.02..{year}.03.20',
#  'lcv_red_landsat.glad.ard_p25_30m_0..0cm_{year}.09.13..{year}.12.01',
#  'lcv_green_landsat.glad.ard_p75_30m_0..0cm_{year_minus_1}.12.02..{year}.03.20',
#  'lcv_red_landsat.glad.ard_p25_30m_0..0cm_{year}.03.21..{year}.06.24',
#  'lcv_red_landsat.glad.ard_p50_30m_0..0cm_{year}.03.21..{year}.06.24',
#  'lcv_red_landsat.glad.ard_p75_30m_0..0cm_{year}.03.21..{year}.06.24',
#  'lcv_red_landsat.glad.ard_p50_30m_0..0cm_{year_minus_1}.12.02..{year}.03.20',
#  'lcv_red_landsat.glad.ard_p25_30m_0..0cm_{year_minus_1}.12.02..{year}.03.20',
#  'lcv_red_landsat.glad.ard_p75_30m_0..0cm_{year_minus_1}.12.02..{year}.03.20',
#  'lcv_blue_landsat.glad.ard_p25_30m_0..0cm_{year}.06.25..{year}.09.12',
#  'lcv_nir_landsat.glad.ard_p25_30m_0..0cm_{year}.09.13..{year}.12.01',
#  'lcv_nir_landsat.glad.ard_p50_30m_0..0cm_{year_minus_1}.12.02..{year}.03.20',
#  'lcv_nir_landsat.glad.ard_p25_30m_0..0cm_{year_minus_1}.12.02..{year}.03.20',
#  'lcv_nir_landsat.glad.ard_p50_30m_0..0cm_{year}.09.13..{year}.12.01',
#  'lcv_nir_landsat.glad.ard_p50_30m_0..0cm_{year}.03.21..{year}.06.24',
#  'lcv_nir_landsat.glad.ard_p75_30m_0..0cm_{year_minus_1}.12.02..{year}.03.20',
#  'lcv_nir_landsat.glad.ard_p50_30m_0..0cm_{year}.06.25..{year}.09.12',
#  'lcv_nir_landsat.glad.ard_p25_30m_0..0cm_{year}.03.21..{year}.06.24',
#  'lcv_nir_landsat.glad.ard_p75_30m_0..0cm_{year}.06.25..{year}.09.12',
#  'lcv_nir_landsat.glad.ard_p25_30m_0..0cm_{year}.06.25..{year}.09.12',
#  'lcv_nir_landsat.glad.ard_p75_30m_0..0cm_{year}.09.13..{year}.12.01',
#  'lcv_thermal_landsat.glad.ard_p75_30m_0..0cm_{year_minus_1}.12.02..{year}.03.20',
#  'lcv_nir_landsat.glad.ard_p75_30m_0..0cm_{year}.03.21..{year}.06.24',
#  'lcv_thermal_landsat.glad.ard_p25_30m_0..0cm_{year_minus_1}.12.02..{year}.03.20',
#  'lcv_thermal_landsat.glad.ard_p50_30m_0..0cm_{year_minus_1}.12.02..{year}.03.20',
#  'lcv_thermal_landsat.glad.ard_p50_30m_0..0cm_{year}.03.21..{year}.06.24',
#  'lcv_thermal_landsat.glad.ard_p25_30m_0..0cm_{year}.03.21..{year}.06.24',
#  'lcv_green_landsat.glad.ard_p50_30m_0..0cm_{year}.03.21..{year}.06.24',
#  'lcv_thermal_landsat.glad.ard_p75_30m_0..0cm_{year}.03.21..{year}.06.24',
#  'lcv_thermal_landsat.glad.ard_p25_30m_0..0cm_{year}.06.25..{year}.09.12',
#  'lcv_thermal_landsat.glad.ard_p75_30m_0..0cm_{year}.06.25..{year}.09.12',
#  'lcv_thermal_landsat.glad.ard_p50_30m_0..0cm_{year}.06.25..{year}.09.12',
#  'lcv_thermal_landsat.glad.ard_p25_30m_0..0cm_{year}.09.13..{year}.12.01',
#  'lcv_thermal_landsat.glad.ard_p75_30m_0..0cm_{year}.09.13..{year}.12.01',
#  'lcv_thermal_landsat.glad.ard_p50_30m_0..0cm_{year}.09.13..{year}.12.01',
#  'lcv_red_landsat.glad.ard_p50_30m_0..0cm_{year}.09.13..{year}.12.01',
#  'lcv_red_landsat.glad.ard_p75_30m_0..0cm_{year}.09.13..{year}.12.01',
#  'lcv_swir1_landsat.glad.ard_p50_30m_0..0cm_{year}.03.21..{year}.06.24',
#  'lcv_swir2_landsat.glad.ard_p25_30m_0..0cm_{year}.06.25..{year}.09.12',
#  'lcv_swir1_landsat.glad.ard_p75_30m_0..0cm_{year}.06.25..{year}.09.12',
#  'lcv_swir1_landsat.glad.ard_p25_30m_0..0cm_{year}.03.21..{year}.06.24',
#  'lcv_swir1_landsat.glad.ard_p25_30m_0..0cm_{year}.06.25..{year}.09.12',
#  'lcv_swir2_landsat.glad.ard_p50_30m_0..0cm_{year}.06.25..{year}.09.12',
#  'lcv_swir1_landsat.glad.ard_p75_30m_0..0cm_{year}.03.21..{year}.06.24',
#  'lcv_swir1_landsat.glad.ard_p50_30m_0..0cm_{year}.06.25..{year}.09.12',
#  'lcv_swir2_landsat.glad.ard_p50_30m_0..0cm_{year_minus_1}.12.02..{year}.03.20',
#  'lcv_swir1_landsat.glad.ard_p75_30m_0..0cm_{year_minus_1}.12.02..{year}.03.20',
#  'lcv_swir2_landsat.glad.ard_p75_30m_0..0cm_{year_minus_1}.12.02..{year}.03.20',
#  'lcv_swir2_landsat.glad.ard_p25_30m_0..0cm_{year}.03.21..{year}.06.24',
#  'lcv_swir2_landsat.glad.ard_p25_30m_0..0cm_{year_minus_1}.12.02..{year}.03.20',
#  'lcv_swir2_landsat.glad.ard_p75_30m_0..0cm_{year}.03.21..{year}.06.24',
#  'lcv_swir2_landsat.glad.ard_p75_30m_0..0cm_{year}.06.25..{year}.09.12',
#  'lcv_swir2_landsat.glad.ard_p25_30m_0..0cm_{year}.09.13..{year}.12.01',
#  'lcv_swir1_landsat.glad.ard_p25_30m_0..0cm_{year}.09.13..{year}.12.01',
#  'lcv_swir2_landsat.glad.ard_p50_30m_0..0cm_{year}.03.21..{year}.06.24',
#  'lcv_swir1_landsat.glad.ard_p50_30m_0..0cm_{year}.09.13..{year}.12.01',
#  'lcv_swir2_landsat.glad.ard_p50_30m_0..0cm_{year}.09.13..{year}.12.01',
#  'lcv_swir1_landsat.glad.ard_p75_30m_0..0cm_{year}.09.13..{year}.12.01',
#  'lcv_swir1_landsat.glad.ard_p25_30m_0..0cm_{year_minus_1}.12.02..{year}.03.20',
#  'lcv_swir1_landsat.glad.ard_p50_30m_0..0cm_{year_minus_1}.12.02..{year}.03.20',
#  'lcv_swir2_landsat.glad.ard_p75_30m_0..0cm_{year}.09.13..{year}.12.01',
#  'lst_mod11a2.daytime_p95_1km_s_{year}0101_{year}0131',
#  'lst_mod11a2.daytime_sd_1km_s_{year}0101_{year}0131',
#  'lst_mod11a2.daytime_p50_1km_s_{year}0101_{year}0131',
#  'lst_mod11a2.daytime_sd_1km_s_{year}0201_{year}0228',
#  'lst_mod11a2.daytime_p05_1km_s_{year}0301_{year}0331',
#  'lst_mod11a2.daytime_p95_1km_s_{year}0201_{year}0228',
#  'lst_mod11a2.daytime_sd_1km_s_{year}0301_{year}0331',
#  'lst_mod11a2.daytime_p50_1km_s_{year}0201_{year}0228',
#  'lst_mod11a2.daytime_sd_1km_s_{year}0401_{year}0430',
#  'lst_mod11a2.daytime_p05_1km_s_{year}0101_{year}0131',
#  'lst_mod11a2.daytime_p95_1km_s_{year}0301_{year}0331',
#  'lst_mod11a2.daytime_p05_1km_s_{year}0201_{year}0228',
#  'lst_mod11a2.daytime_sd_1km_s_{year}0501_{year}0531',
#  'lst_mod11a2.daytime_sd_1km_s_{year}0601_{year}0630',
#  'lst_mod11a2.daytime_sd_1km_s_{year}0701_{year}0731',
#  'lst_mod11a2.daytime_p95_1km_s_{year}0401_{year}0430',
#  'lst_mod11a2.daytime_sd_1km_s_{year}0801_{year}0831',
#  'lst_mod11a2.daytime_p05_1km_s_{year}0401_{year}0430',
#  'lst_mod11a2.daytime_p50_1km_s_{year}0401_{year}0430',
#  'lst_mod11a2.daytime.m02_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime_p50_1km_s_{year}0501_{year}0531',
#  'lst_mod11a2.daytime_p95_1km_s_{year}0601_{year}0630',
#  'lst_mod11a2.daytime_p05_1km_s_{year}0501_{year}0531',
#  'lst_mod11a2.daytime_sd_1km_s_{year}0901_{year}0930',
#  'lst_mod11a2.daytime_p95_1km_s_{year}0701_{year}0731',
#  'lst_mod11a2.daytime_p50_1km_s_{year}0601_{year}0630',
#  'lst_mod11a2.daytime_sd_1km_s_{year}1001_{year}1031',
#  'lst_mod11a2.daytime.m03_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime_sd_1km_s_{year}1201_{year}1231',
#  'lst_mod11a2.daytime_p05_1km_s_{year}0601_{year}0630',
#  'lst_mod11a2.daytime.m02_p50_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime_p50_1km_s_{year}0701_{year}0731',
#  'lst_mod11a2.daytime.m02_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime_p05_1km_s_{year}0901_{year}0930',
#  'lst_mod11a2.daytime_p50_1km_s_{year}0801_{year}0831',
#  'lst_mod11a2.daytime_p95_1km_s_{year}0801_{year}0831',
#  'lst_mod11a2.daytime.m04_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime_p50_1km_s_{year}0901_{year}0930',
#  'lst_mod11a2.daytime_p95_1km_s_{year}0501_{year}0531',
#  'lst_mod11a2.daytime_p50_1km_s_{year}1201_{year}1231',
#  'lst_mod11a2.daytime_p50_1km_s_{year}1101_{year}1130',
#  'lst_mod11a2.daytime_p95_1km_s_{year}1201_{year}1231',
#  'lst_mod11a2.daytime_p95_1km_s_{year}1001_{year}1031',
#  'lst_mod11a2.daytime.m05_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime_p05_1km_s_{year}0801_{year}0831',
#  'lst_mod11a2.daytime_p50_1km_s_{year}1001_{year}1031',
#  'lst_mod11a2.daytime_p95_1km_s_{year}1101_{year}1130',
#  'lst_mod11a2.daytime_p95_1km_s_{year}0901_{year}0930',
#  'lst_mod11a2.daytime_p05_1km_s_{year}1001_{year}1031',
#  'lst_mod11a2.daytime_p05_1km_s_{year}1201_{year}1231',
#  'lst_mod11a2.daytime.m02_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m03_p50_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m03_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m03_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m04_p50_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m06_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m04_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m04_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m05_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m05_p50_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime_sd_1km_s_{year}1101_{year}1130',
#  'lst_mod11a2.daytime.m05_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m10_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m09_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m08_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m11_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m06_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m06_p50_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m06_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m07_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m07_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m07_p50_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m07_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m08_p50_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m09_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m08_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m12_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m11_p50_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m11_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m12_p50_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m09_p50_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m08_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime_sd_1km_s_{year}0101_{year}1231',
#  'lst_mod11a2.daytime.m10_p50_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m10_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m09_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime_p05_1km_s_{year}1101_{year}1130',
#  'lst_mod11a2.daytime.m10_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m11_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.m12_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime_p05_1km_s_{year}0701_{year}0731',
#  'lst_mod11a2.daytime.m12_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.daytime.trend_p50_1km_s_{year}0101_{year}0131',
#  'lst_mod11a2.daytime.trend_p50_1km_s_{year}0601_{year}0630',
#  'lst_mod11a2.daytime_p05_1km_s_{year}0101_{year}1231',
#  'lst_mod11a2.daytime_p50_1km_s_{year}0101_{year}1231',
#  'lst_mod11a2.daytime_p95_1km_s_{year}0101_{year}1231',
#  'lst_mod11a2.daytime.trend_p50_1km_s_{year}0201_{year}0228',
#  'lst_mod11a2.daytime.trend_p50_1km_s_{year}1201_{year}1231',
#  'lst_mod11a2.nighttime_p95_1km_s_{year}0401_{year}0430',
#  'lst_mod11a2.nighttime_p95_1km_s_{year}0301_{year}0331',
#  'lst_mod11a2.nighttime_sd_1km_s_{year}0101_{year}0131',
#  'lst_mod11a2.nighttime_p50_1km_s_{year}0301_{year}0331',
#  'lst_mod11a2.nighttime_p50_1km_s_{year}0201_{year}0228',
#  'lst_mod11a2.nighttime_p05_1km_s_{year}0501_{year}0531',
#  'lst_mod11a2.nighttime_p50_1km_s_{year}0101_{year}0131',
#  'lst_mod11a2.nighttime_p95_1km_s_{year}0201_{year}0228',
#  'lst_mod11a2.nighttime_sd_1km_s_{year}0401_{year}0430',
#  'lst_mod11a2.daytime_p50_1km_s_{year}0301_{year}0331',
#  'lst_mod11a2.nighttime_p05_1km_s_{year}0601_{year}0630',
#  'lst_mod11a2.nighttime_p50_1km_s_{year}0501_{year}0531',
#  'lst_mod11a2.nighttime_sd_1km_s_{year}0301_{year}0331',
#  'lst_mod11a2.nighttime_p05_1km_s_{year}0101_{year}0131',
#  'lst_mod11a2.nighttime_sd_1km_s_{year}0501_{year}0531',
#  'lst_mod11a2.nighttime_sd_1km_s_{year}0201_{year}0228',
#  'lst_mod11a2.nighttime_p05_1km_s_{year}0701_{year}0731',
#  'lst_mod11a2.nighttime_sd_1km_s_{year}0801_{year}0831',
#  'lst_mod11a2.nighttime_sd_1km_s_{year}0901_{year}0930',
#  'lst_mod11a2.nighttime_p95_1km_s_{year}0701_{year}0731',
#  'lst_mod11a2.nighttime_p05_1km_s_{year}0401_{year}0430',
#  'lst_mod11a2.nighttime_sd_1km_s_{year}1101_{year}1130',
#  'lst_mod11a2.nighttime_sd_1km_s_{year}0701_{year}0731',
#  'lst_mod11a2.nighttime_sd_1km_s_{year}1001_{year}1031',
#  'lst_mod11a2.nighttime_sd_1km_s_{year}0601_{year}0630',
#  'lst_mod11a2.nighttime_p50_1km_s_{year}0701_{year}0731',
#  'lst_mod11a2.nighttime_p05_1km_s_{year}0801_{year}0831',
#  'lst_mod11a2.nighttime_p05_1km_s_{year}0301_{year}0331',
#  'lst_mod11a2.nighttime_p95_1km_s_{year}0801_{year}0831',
#  'lst_mod11a2.nighttime_p50_1km_s_{year}1001_{year}1031',
#  'lst_mod11a2.nighttime_p95_1km_s_{year}1101_{year}1130',
#  'lst_mod11a2.nighttime.m02_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime_sd_1km_s_{year}1201_{year}1231',
#  'lst_mod11a2.nighttime_p95_1km_s_{year}0101_{year}0131',
#  'lst_mod11a2.nighttime_p95_1km_s_{year}0501_{year}0531',
#  'lst_mod11a2.nighttime_p50_1km_s_{year}1101_{year}1130',
#  'lst_mod11a2.nighttime_p05_1km_s_{year}1001_{year}1031',
#  'lst_mod11a2.nighttime_p50_1km_s_{year}0801_{year}0831',
#  'lst_mod11a2.nighttime_p50_1km_s_{year}0401_{year}0430',
#  'lst_mod11a2.nighttime_p05_1km_s_{year}0901_{year}0930',
#  'lst_mod11a2.nighttime_p95_1km_s_{year}0601_{year}0630',
#  'lst_mod11a2.nighttime_p95_1km_s_{year}1001_{year}1031',
#  'lst_mod11a2.nighttime_p05_1km_s_{year}0201_{year}0228',
#  'lst_mod11a2.nighttime_p50_1km_s_{year}0601_{year}0630',
#  'lst_mod11a2.nighttime.m03_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime_p05_1km_s_{year}1101_{year}1130',
#  'lst_mod11a2.nighttime.m05_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m06_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m02_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime_p95_1km_s_{year}1201_{year}1231',
#  'lst_mod11a2.nighttime.m02_p50_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m04_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m08_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m02_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime_p50_1km_s_{year}0901_{year}0930',
#  'lst_mod11a2.nighttime.m09_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m07_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m05_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m03_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime_p50_1km_s_{year}1201_{year}1231',
#  'lst_mod11a2.nighttime.m03_p50_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime_p05_1km_s_{year}1201_{year}1231',
#  'lst_mod11a2.nighttime.m10_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m11_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m06_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m03_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime_p95_1km_s_{year}0901_{year}0930',
#  'lst_mod11a2.nighttime.m07_p50_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m04_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m04_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m12_sd_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m05_p50_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m08_p50_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m06_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m08_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime_sd_1km_s_{year}0101_{year}1231',
#  'lst_mod11a2.nighttime.m09_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m08_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m05_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m07_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m11_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m10_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m07_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m09_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m09_p50_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m11_p50_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m12_p50_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m12_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m10_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m11_p05_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m12_p95_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime.m06_p50_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime_p50_1km_s_{year}0101_{year}1231',
#  'lst_mod11a2.nighttime.trend_p50_1km_s_{year}0101_{year}0131',
#  'lst_mod11a2.nighttime.trend_p50_1km_s_{year}0901_{year}0930',
#  'lst_mod11a2.nighttime.trend_p50_1km_s_{year}0401_{year}0430',
#  'lst_mod11a2.nighttime.m10_p50_1km_s_20000101_20211231',
#  'lst_mod11a2.nighttime_p05_1km_s_{year}0101_{year}1231',
#  'lst_mod11a2.nighttime_p95_1km_s_{year}0101_{year}1231',
#  'lst_mod11a2.nighttime.trend_p50_1km_s_{year}1101_{year}1130',
#  'lst_mod11a2.nighttime.trend_p50_1km_s_{year}0301_{year}0331',
#  'lst_mod11a2.nighttime.trend_p50_1km_s_{year}1201_{year}1231',
#  'lst_mod11a2.nighttime.trend_p50_1km_s_{year}0201_{year}0228',
#  'accum.precipitation_chelsa.montlhy_m_1km_s_{year}0201_{year}0228',
#  'accum.precipitation_chelsa.montlhy_m_1km_s_{year}0801_{year}0831',
#  'accum.precipitation_chelsa.montlhy_m_1km_s_{year}0501_{year}0531',
#  'accum.precipitation_chelsa.montlhy_m_1km_s_{year}0401_{year}0430',
#  'accum.precipitation_chelsa.annual.3years.dif_m_1km_s_{year}0101_{year}1231',
#  'accum.precipitation_chelsa.montlhy_m_1km_s_{year}1101_{year}1130',
#  'accum.precipitation_chelsa.montlhy_m_1km_s_{year}0601_{year}0630',
#  'accum.precipitation_chelsa.montlhy_m_1km_s_{year}1201_{year}1231',
#  'accum.precipitation_chelsa.montlhy_m_1km_s_{year}1001_{year}1031',
#  'accum.precipitation_chelsa.annual_m_1km_s_{year}0101_{year}1231',
#  'lst_mod11a2.nighttime.m04_p50_1km_s_20000101_20211231',
#  'accum.precipitation_chelsa.annual.log.csum_m_1km_s_{year}0101_{year}1231',
#  'accum.precipitation_chelsa.montlhy_m_1km_s_{year}0301_{year}0331',
#  'accum.precipitation_chelsa.montlhy_m_1km_s_{year}0701_{year}0731',
#  'accum.precipitation_chelsa.montlhy_m_1km_s_{year}0101_{year}0131',
#  'accum.precipitation_chelsa.montlhy_m_1km_s_{year}0901_{year}0930',
#  'bioclim.var_chelsa.bio11_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.bio10_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.bio2_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.bio1_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.bio3_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.bio5_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.bio8_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.bio9_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.ngd0_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.gsl_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.ngd5_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.bio17_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.gst_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.bio6_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.bio15_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.bio7_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.ngd10_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.bio16_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.bio14_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.bio13_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.bio12_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.bio18_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.gdd5_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.gsp_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.npp_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.gdd0_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.bio4_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.bio19_m_1km_s_19810101_20101231',
#  'bioclim.var_chelsa.gdd10_m_1km_s_19810101_20101231']

# %%
omit = list(np.array(feat_cols)[~rfe.support_])
omit
# Out:
# ['dtm_surface.lithology_egdi.1m.alkaliolivinebasalt_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.arenite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.amphibolite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.andesite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.biogenicsilicasedimentaryrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.carbonatite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.clasticsedimentarymaterial_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.breccia_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.chalk_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.ashtufflapillistoneandlapillituff_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.ashbrecciabomborblocktephra_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.basanite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.brecciagougeseries_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.basalt_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.chloriteactinoliteepidotemetamorphicrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.carbonateooze_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.carbonatesedimentaryrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.diamicton_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.doleriticrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.carbonatemud_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.dolomite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.clasticsandstone_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.anorthositicrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.conglomerate_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.dacite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.dioriticrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.diamictite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.fragmentaligneousmaterial_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.dolomiticormagnesiansedimentaryrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.diorite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.clasticsedimentaryrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.exoticcompositionigneousrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.claystone_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.foidbearingsyenite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.foidsyenitoid_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.gabbroicrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.finegrainedigneousrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.eclogite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.foliatedmetamorphicrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.gneiss_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.gabbroid_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.gabbro_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.hornfels_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.granite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.impactgeneratedmaterial_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.granulite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.granodiorite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.glaucophanelawsoniteepidotemetamorphicrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.marble_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.gravel_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.igneousmaterial_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.impurelimestone_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.limestone_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.metasomaticrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.impurecarbonatesediment_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.igneousrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.granitoid_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.orthogneiss_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.migmatite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.nonclasticsiliceoussedimentaryrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.komatiiticrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.organicrichsediment_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.impurecarbonatesedimentaryrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.organicbearingmudstone_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.impuredolomite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.myloniticrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.monzogranite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.metamorphicrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.micaschist_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.gypsumoranhydrite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.organicrichsedimentarymaterial_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.phyllonite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.mudstone_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.phonolite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.paragneiss_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.mud_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.phyllite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.phaneriticigneousrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.monzonite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.pyroclasticrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.peridotite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.pyroxenite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.porphyry_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.pyroclasticmaterial_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.quartzdiorite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.rock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.quartzite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.schist_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.shale_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.sedimentaryrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.residualmaterial_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.rhyolite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.tephrite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.syeniticrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.sedimentarymaterial_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.rhyolitoid_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.serpentinite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.sand_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.syenogranite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.sediment_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.skarn_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.silicatemud_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.trachyticrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.tonalite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.silt_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.trachyte_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.slate_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.syenite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.ultramaficigneousrock_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.tholeiiticbasalt_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.tuffbrecciaagglomerateorpyroclasticbreccia_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.trachytoid_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.spilite_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.siltstone_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.travertine_p_250m_2018',
#  'dtm_surface.lithology_egdi.1m.sandstone_p_250m_2018',
#  'evi_mod13q1.v061.trend.logit.ols.alpha_l.025_250m_s_20000101_20211231',
#  'evi_mod13q1.v061.trend.logit.ols.alpha_u.975_250m_s_20000101_20211231',
#  'ndvi_mod13q1.v061.trend_p50_250m_s_{year}0501_{year}0531',
#  'ndvi_mod13q1.v061.trend_p50_250m_s_{year}0701_{year}0731',
#  'ndvi_mod13q1.v061.trend_p50_250m_s_{year}0901_{year}0930',
#  'ndvi_mod13q1.v061.trend_p50_250m_s_{year}0801_{year}0831',
#  'ndvi_mod13q1.v061.trend_p50_250m_s_{year}0401_{year}0430',
#  'ndvi_mod13q1.v061.trend_p50_250m_s_{year}1001_{year}1031',
#  'red_mod13q1.m06.log_p50_250m_s_20000101_20211231',
#  'nir_mod13q1.m08.log_p75_250m_s_20000101_20211231',
#  'nir_mod13q1.m08.log_p25_250m_s_20000101_20211231',
#  'nir_mod13q1.m04.log_p50_250m_s_20000101_20211231',
#  'nir_mod13q1.m06.log_p50_250m_s_20000101_20211231',
#  'nir_mod13q1.m05.log_p50_250m_s_20000101_20211231',
#  'nir_mod13q1.m06.log_p25_250m_s_20000101_20211231',
#  'nir_mod13q1.m07.log_p50_250m_s_20000101_20211231',
#  'nir_mod13q1.m06.log_p75_250m_s_20000101_20211231',
#  'nir_mod13q1.m11.log_p50_250m_s_20000101_20211231',
#  'nir_mod13q1.m10.log_p75_250m_s_20000101_20211231',
#  'nir_mod13q1.m09.log_p50_250m_s_20000101_20211231',
#  'nir_mod13q1.m09.log_p75_250m_s_20000101_20211231',
#  'nir_mod13q1.m11.log_p75_250m_s_20000101_20211231',
#  'nir_mod13q1.m10.log_p50_250m_s_20000101_20211231',
#  'mir_mod13q1.m08.log_p50_250m_s_20000101_20211231',
#  'mir_mod13q1.m07.log_p50_250m_s_20000101_20211231',
#  'mir_mod13q1.m07.log_p75_250m_s_20000101_20211231',
#  'mir_mod13q1.m09.log_p75_250m_s_20000101_20211231',
#  'mir_mod13q1.m09.log_p50_250m_s_20000101_20211231',
#  'mir_mod13q1.m09.log_p25_250m_s_20000101_20211231',
#  'pft.snowice_esa.cci.lc_pc_250m_s_{year}0101_{year}1231',
#  'lst_mod11a2.daytime.trend_p50_1km_s_{year}0301_{year}0331',
#  'lst_mod11a2.daytime.trend_p50_1km_s_{year}0701_{year}0731',
#  'lst_mod11a2.daytime.trend_p50_1km_s_{year}0401_{year}0430',
#  'lst_mod11a2.daytime.trend_p50_1km_s_{year}0801_{year}0831',
#  'lst_mod11a2.daytime.trend_p50_1km_s_{year}1101_{year}1130',
#  'lst_mod11a2.daytime.trend_p50_1km_s_{year}0501_{year}0531',
#  'lst_mod11a2.daytime.trend_p50_1km_s_{year}0901_{year}0930',
#  'lst_mod11a2.daytime.trend_p50_1km_s_{year}1001_{year}1031',
#  'lst_mod11a2.nighttime.trend_p50_1km_s_{year}1001_{year}1031',
#  'lst_mod11a2.nighttime.trend_p50_1km_s_{year}0601_{year}0630',
#  'lst_mod11a2.nighttime.trend_p50_1km_s_{year}0701_{year}0731',
#  'lst_mod11a2.nighttime.trend_p50_1km_s_{year}0801_{year}0831',
#  'lst_mod11a2.nighttime.trend_p50_1km_s_{year}0501_{year}0531',
#  'bioclim.var_chelsa.scd_m_1km_s_19810101_20101231']

# %%
# Set up cross-validation
score = pd.DataFrame()
score['feat_num'] = np.arange(len(feat_cols)+1,1,-10)
score['score'] = rfecv.cv_results_['mean_test_score']

plt.plot(score['feat_num'], score['score'], marker='o')
plt.xlabel('Number of Features')
plt.ylabel('Cross-Validation Negative Mean Squared Error')
plt.title(f'Scree Plot')
plt.show()

best_feature_index = score['score'].idxmax()
best = score.iloc[best_feature_index]['feat_num']

# %%
with open('/mnt/inca/soc_eu_model/feature_selection/test.txt', 'w') as file:
    for item in grid_scores:
        file.write(str(item) + '\n')
        
list_strings = data_string.strip("[]").split("],")

# Convert each list string to an actual list
lists = [ast.literal_eval(s.strip()) for s in list_strings]

file_path = "/mnt/inca/soc_eu_model/feature_selection/test.txt"  # Replace with the path to your text file
lines = []
with open(file_path, "r") as file:
    for line in file:
        lines.append(line.strip())
        
line = ''
for i in range(len(lines)):
    line = line+lines[i]
line1 = line.split('][')[0][1::]
line2 = line.split('][')[1][0:-1]

import re
numl1 = [num for num in re.split(r'[-\s]+', line1)]
numl1 = [float(num)*(-1) for num in numl1 if num != '']

numl2 = [num for num in re.split(r'[-\s]+', line2)]
numl2 = [float(num)*(-1) for num in numl2 if num != '']

plt.plot(featn,numl1, marker='o',label='trial-1')
plt.plot(featn,numl2, marker='o',label='trial-2')
plt.xlabel('Number of Features')
plt.ylabel('Cross-Validation Negative Mean Squared Error')
plt.title(f'Scree Plot')
plt.legend()
plt.show()

# best_feature_index = score['score'].idxmax()
# best = score.iloc[best_feature_index]['feat_num']

# %%
from sklearn.model_selection import GroupKFold, KFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFECV, RFE
from scipy.signal import argrelmin
import joblib

def run_feature_selection(data, covs, target_column, spatial_cv_column = None, 
                          subsample_pct = 0.1, n_rep = 5, n_cv = 5, ntrees = 50, local_min_pos = 1):

    rfecv_step = int(len(covs) * 0.1)
    rfe_step = int(rfecv_step / 2)
    

    cv, groups = KFold(n_cv), None
    if spatial_cv_column is not None:
        cv, groups = GroupKFold(n_cv), data[spatial_cv_column]

    ncpu = multiprocessing.cpu_count()
    if ntrees < ncpu:
        ncpu = ntrees

    ttprint(f"Finding n_features_to_select using RFECV (repetitions={n_rep} step={rfecv_step})")
    
    grid_scores = []
    for i in range(0,n_rep):
        rfecv = RFECV(estimator=RandomForestRegressor(ntrees, n_jobs=ncpu, random_state=i), cv=cv, step=rfecv_step, 
            min_features_to_select=10, n_jobs=n_cv, scoring=scoring, verbose=1)
        rfecv.fit(data[covs], data[target_column], groups=groups)
        grid_scores += [rfecv.cv_results_['mean_test_score']]

    rfecv_mean_score = np.mean(np.stack(grid_scores, axis=0), axis=0)
    grid_scores_std = np.std(np.stack(grid_scores, axis=0), axis=0)

    rfecv_n_features_arr = list(range(rfecv.min_features_to_select, len(covs)+rfecv.step, rfecv.step))

    local_min_arr = argrelmin(rfecv_mean_score, order=1)[0]
    local_min = local_min_arr[0]
    if len(local_min_arr) > 1:
        local_min = local_min_arr[local_min_pos]

    n_features_to_select = rfecv_n_features_arr[local_min]

    ttprint(f"Finding best features using RFE (n_features_to_select = {n_features_to_select})")

    rfe = RFE(estimator=RandomForestRegressor(ntrees, n_jobs=ncpu, random_state=n_rep), step=rfe_step, n_features_to_select=n_features_to_select, verbose=1)
    rfe.fit(data[covs], data[target_column])

    result = list(np.array(covs)[rfe.support_])
    
    return result, rfecv_n_features_arr, rfecv_mean_score, grid_scores_std

fn_rfcv = Path(f'model_{target_col}_v1.1_rfecv.lz4', compress='lz4')
if Path(fn_rfcv).exists():
    locals().update(joblib.load(fn_rfcv))
else:
    print("Executing")
    covs_rfe, rfecv_n_features_arr, rfecv_mean_score, rfecv_std_score = run_feature_selection(data=samples, covs=feat_cols, target_column=target_col, spatial_cv_column=cv_group_col, ntrees=60, local_min_pos=1)
    joblib.dump({
        'covs_rfe':covs_rfe, 
        'rfecv_n_features_arr': rfecv_n_features_arr, 
        'rfecv_mean_score': rfecv_mean_score,
        'rfecv_std_score': rfecv_std_score
    }, fn_rfcv)

#covs_rfe, rfecv_n_features_arr, rfecv_mean_score, rfecv_std_score = run_feature_selection(data=samples, covs=feat_cols, target_column=target_col, spatial_cv_column=cv_group_col)

# %%
# %history
# Out:
# import numpy as np
# import matplotlib.pyplot as plt
# import multiprocess as mp
# import glob
# import time
# from tqdm import tqdm
# import os
# import sys
# import pandas as pd
# from eumap.misc import find_files
# from eumap.raster import read_rasters, save_rasters
# from eumap.mapper import SpaceOverlay
# import geopandas as gpd
# from pathlib import Path
# import rasterio
# import pyproj
# from shapely.geometry import Point
# from eumap.mapper import LandMapper
#
# import warnings
#
# import matplotlib
# import matplotlib.pyplot as plt
#
# from sklearn.experimental import enable_halving_search_cv
# from sklearn.model_selection import train_test_split, cross_val_score, HalvingGridSearchCV, KFold, GroupKFold
# from sklearn.metrics import mean_squared_error, r2_score
# from sklearn.feature_selection import RFECV
# from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, StackingRegressor
# from sklearn.linear_model import Ridge, LinearRegression
# from sklearn.pipeline import Pipeline
# from sklearn.neural_network import MLPRegressor
# from sklearn.ensemble import StackingRegressor
#
# import joblib
# import pickle
# df = pd.read_csv('training_points_v3.1_covar.csv',low_memory=False)
# df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
# print(len(df))
# df = df.drop(df.loc[df['oc']=='<6'].index) # 231
# print(len(df))
# df = df.drop(df.loc[df['oc']=='< LOD'].index)  # 33, lucas 2018
# print(len(df))
# df = df.drop(df.loc[df['oc']=='<0.0'].index)  # 2, lucas 2018
# print(len(df))
# df['oc'] = pd.to_numeric(df['oc'], errors='coerce')
# df = df.drop(df.loc[df['oc']<0].index)
# print(len(df))
# feat_cols = df.columns.values.tolist()
# rm_list = ['ph_h2o','ph_ca','gps_lat','gps_long','time','ref','ph_kcl','country','oc']
# for i in rm_list:
#     feat_cols.remove(i)
#
# tgt_col = ['oc']
# dff = df[tgt_col+feat_cols+['country']]
#
# rm_list = dff.columns[dff.isna().sum()>500].values.tolist()
# for i in ['oc','hzn_bottom']:
#     rm_list.remove(i)
#
# dff = dff.drop(columns=rm_list)
# for i in rm_list:
#     feat_cols.remove(i)
#
#
# dff['oc_log'] = np.log1p(dff['oc'].values)
# a = len(dff.loc[dff['oc_log'].isna()])
# print(f'{a} with nan OC values')
# dff = dff.dropna(how='any')
# dff = dff.reset_index(drop=True)
# print(f'original feature numbers: {len(feat_cols)}')
# print(f'{len(dff)} left after dropna')
#
# tgt_col = ['oc_log']
# # x_slc, x_test, y_slc, y_test = train_test_split(dff[feat_cols], dff[tgt_col], test_size=0.6, random_state=1)
# df_slc, df_test = train_test_split(dff, test_size=0.7, random_state=42)
#
# cv, groups = GroupKFold(5), df_slc['country']
#
# # rfecv = RFECV(estimator=RandomForestRegressor(), step=30, cv=5, min_features_to_select=30, scoring='neg_mean_squared_error',n_jobs=50)
# # warnings.filterwarnings('ignore')
# # rfecv.fit(x_slc, y_slc)
#
# # selected_feature_indices = np.where(rfecv.support_)[0]
# # selected_features = [feat_cols[i] for i in selected_feature_indices]
# # selected_features
# names = ['score_mean','score_std','optimal_feature_number','feature_importance']
# dfe = pd.DataFrame(columns=names)
# dfe
# warnings.filterwarnings(action='ignore')
#
# grid_score_mean = []
# grid_score_std = []
# opti_feat_num = []
# grid_feat_import = []
# grid_feat = []
# for i in [0,1,2,3,4]:
#     rfecv = RFECV(estimator=RandomForestRegressor(200, n_jobs=60, random_state=i), cv=cv, step=20,
#                   min_features_to_select=30, n_jobs=1, scoring='neg_mean_squared_error', verbose=1)
#     rfecv.fit(df_slc[feat_cols], df_slc[tgt_col].values, groups=groups)
#
#     grid_score_mean += [rfecv.cv_results_['mean_test_score']]
#     grid_score_std += [rfecv.cv_results_["std_test_score"]]
#     opti_feat_num.append(rfecv.n_features_)
#     grid_feat_import.append(rfecv.estimator_.feature_importances_)
#
#     dfe.loc[len(dfe)]=[rfecv.cv_results_['mean_test_score'],rfecv.cv_results_["std_test_score"],rfecv.n_features_,rfecv.estimator_.feature_importances_]
#     dfe.to_csv('/mnt/inca/soc_eu_model/feature_selection/evaluation_matrix.csv')
#
#     selected_feature_indices = np.where(rfecv.support_)[0]
#     selected_features = [feat_cols[i] for i in selected_feature_indices]
#     grid_feat.append(selected_features)
# warnings.filterwarnings(action='ignore')
#
# grid_score_mean = []
# grid_score_std = []
# opti_feat_num = []
# grid_feat_import = []
# grid_feat = []
# for i in [0,1,2,3,4]:
#     rfecv = RFECV(estimator=RandomForestRegressor(200, n_jobs=60, random_state=i), cv=cv, step=20,
#                   min_features_to_select=30, n_jobs=1, scoring='neg_mean_squared_error', verbose=1)
#     rfecv.fit(df_slc[feat_cols], df_slc[tgt_col].values, groups=groups)
#
#     grid_score_mean += [rfecv.cv_results_['mean_test_score']]
#     grid_score_std += [rfecv.cv_results_["std_test_score"]]
#     opti_feat_num.append(rfecv.n_features_)
#     grid_feat_import.append(rfecv.estimator_.feature_importances_)
#
#     dfe.loc[len(dfe)]=[rfecv.cv_results_['mean_test_score'],rfecv.cv_results_["std_test_score"],rfecv.n_features_,rfecv.estimator_.feature_importances_]
#     dfe.to_csv('/mnt/inca/soc_eu_model/feature_selection/evaluation_matrix_log.csv')
#
#     selected_feature_indices = np.where(rfecv.support_)[0]
#     selected_features = [feat_cols[i] for i in selected_feature_indices]
#     grid_feat.append(selected_features)
# featn = np.arange(782,10,-20)
# featn = featn[::-1]
#
# for i in [0,1,2,3,4]:
#     plt.plot(featn,grid_score_mean[i], marker='o',label=f'trial-{i}')
#     plt.xlabel('Number of Features')
#     plt.ylabel('Cross-Validation Negative Mean Squared Error')
#     plt.title(f'Scree Plot')
#     plt.legend()
#     plt.show()
# dfe['optimal_feature_number']
# dfe['score_mean']
# featn = np.arange(782,10,-20)
# featn = featn[::-1]
#
# for i in [0,1,2,3,4]:
# #     plt.plot(featn,grid_score_mean[i], marker='o',label=f'trial-{i}')
#     plt.errorbar(featn,grid_score_mean[i],grid_score_std[i],label=f'trial-{i}')
#
#     plt.xlabel('Number of Features')
#     plt.ylabel('Cross-Validation Negative Mean Squared Error')
#     plt.title(f'Scree Plot')
#     plt.legend()
#     plt.show()
# featn = np.arange(782,10,-20)
# featn = featn[::-1]
#
# for i in [0,1,2,3,4]:
#     plt.plot(featn,grid_score_mean[i], marker='o',label=f'trial-{i}')
# #     plt.errorbar(featn,grid_score_mean[i],grid_score_std[i],label=f'trial-{i}')
#
#     plt.xlabel('Number of Features')
#     plt.ylabel('Cross-Validation Negative Mean Squared Error')
#     plt.title(f'Scree Plot')
#     plt.legend()
#     plt.show()
# featn = np.arange(782,10,-20)
# featn = featn[::-1]
#
# for i in [0,1,2,3,4]:
#     plt.plot(featn,grid_score_mean[i], marker='o',label=f'trial-{i}')
# #     plt.errorbar(featn,grid_score_mean[i],grid_score_std[i],label=f'trial-{i}')
#     plt.ylim(-2.05,-1.6)
#     plt.xlabel('Number of Features')
#     plt.ylabel('Cross-Validation Negative Mean Squared Error')
#     plt.title(f'Scree Plot')
#     plt.legend()
#     plt.show()
# featn = np.arange(782,10,-20)
# featn = featn[::-1]
#
# for i in [0,1,2,3,4]:
#     plt.plot(featn,grid_score_mean[i], marker='o',label=f'trial-{i}')
# #     plt.errorbar(featn,grid_score_mean[i],grid_score_std[i],label=f'trial-{i}')
#     plt.ylim(-2.1,-1.6)
#     plt.xlabel('Number of Features')
#     plt.ylabel('Cross-Validation Negative Mean Squared Error')
#     plt.title(f'Scree Plot')
#     plt.legend()
#     plt.show()
# dfe
# mean = []
# for column in dfe.columns.values.tolist():
#     temp = []
#     for index, row in df.iterrows():
#         temp.append(row[column])
#
#     temp = np.array(temp)
#     mean.append(p,axis=1))
# mean = []
# for column in dfe.columns.values.tolist():
#     temp = []
#     for index, row in df.iterrows():
#         temp.append(row[column])
#
#     temp = np.array(temp)
#     mean.append(n,axis=1))
# featn = np.arange(782,10,-20)
# featn = featn[::-1]
#
# for i in [0,1,2,3,4]:
#     plt.plot(featn,grid_score_mean[i], marker='o',label=f'trial-{i}')
# #     plt.errorbar(featn,grid_score_mean[i],grid_score_std[i],label=f'trial-{i}')
#     plt.ylim(-2.1,-1.6)
#     plt.xlabel('Number of Features')
#     plt.ylabel('Cross-Validation Negative Mean Squared Error')
#     plt.title(f'Scree Plot')
#     plt.legend()
#     plt.show()
# mean = []
# for column in dfe.columns.values.tolist():
#     temp = []
#     for index, row in df.iterrows():
#         temp.append(row[column])
#
#     temp = np.array(temp)
#     mean.append(np.mean(temp,axis=1))
# temp
# dfe
# mean = []
# for column in dfe.columns.values.tolist():
#     temp = []
#     for index, row in dfe.iterrows():
#         temp.append(row[column])
#
#     temp = np.array(temp)
#     mean.append(np.mean(temp,axis=1))
# column
# temp
# mean = []
# for column in dfe.columns.values.tolist():
#     temp = []
#     for index, row in dfe.iterrows():
#         temp.append(row[column])
#
#     temp = np.array(temp)
#     if len(temp[0])>1:
#         mean.append(np.mean(temp,axis=1))
#     else:
#         mean.append(np.mean(temp))
# mean = []
# for column in dfe.columns.values.tolist():
#     temp = []
#     for index, row in dfe.iterrows():
#         temp.append(row[column])
#
#     temp = np.array(temp)
#     if isinstance(temp[0],list)>1:
#         mean.append(np.mean(temp,axis=1))
#     else:
#         mean.append(np.mean(temp))
# mean = []
# for column in dfe.columns.values.tolist():
#     temp = []
#     for index, row in dfe.iterrows():
#         temp.append(row[column])
#
#     temp = np.array(temp)
#     if isinstance(temp[0],list):
#         mean.append(np.mean(temp,axis=1))
#     else:
#         mean.append(np.mean(temp))
# mean = []
# for column in dfe.columns.values.tolist():
#     temp = []
#     for index, row in dfe.iterrows():
#         temp.append(row[column])
#
#     temp = np.array(temp)
#     if isinstance(temp[0],array):
#         mean.append(np.mean(temp,axis=1))
#     else:
#         mean.append(np.mean(temp))
# mean = []
# for column in dfe.columns.values.tolist():
#     temp = []
#     for index, row in dfe.iterrows():
#         temp.append(row[column])
#
#     temp = np.array(temp)
#     if isinstance(temp[0],np.array):
#         mean.append(np.mean(temp,axis=1))
#     else:
#         mean.append(np.mean(temp))
# temp[0]
# temp.shape
# mean = []
# for column in dfe.columns.values.tolist():
#     temp = []
#     for index, row in dfe.iterrows():
#         temp.append(row[column])
#
#     temp = np.array(temp)
#     mean.append(np.mean(temp,axis=1))
# temp.shape
# len(temp.shape)
# mean = []
# for column in dfe.columns.values.tolist():
#     temp = []
#     for index, row in dfe.iterrows():
#         temp.append(row[column])
#
#     temp = np.array(temp)
#     if len(temp.shape)>1:
#         mean.append(np.mean(temp,axis=1))
#     else:
#         mean.append(np.mean(temp))
# temp
# mean = []
# for column in dfe.columns.values.tolist():
#     temp = []
#     for index, row in dfe.iterrows():
#         temp.append(row[column])
#
#     temp = np.array(temp)
#     if len(temp.shape)>1:
#         mean.append(np.mean(temp,axis=1))
#     else:
#         mean.append(np.mean(temp))
# temp
# column
# mean
# mean.append(np.nan)
# mean
# dfe.loc[len(dfe)] = mean
# dfe
# dfe['trial'] = ['trial-0','trial-1','trial-2','trial-3','trial-4','trial-mean']
# dfe
# dfe.to_csv('/mnt/inca/soc_eu_model/feature_selection/evaluation_matrix_log.csv')
# # mean = []
# # for column in dfe.columns.values.tolist():
# #     temp = []
# #     for index, row in dfe.iterrows():
# #         temp.append(row[column])
#
# #     temp = np.array(temp)
# #     if len(temp.shape)>1:
# #         mean.append(np.mean(temp,axis=1))
# #     else:
# #         mean.append(np.mean(temp))
# featn = np.arange(782,10,-20)
# featn = featn[::-1]
#
# for index, row in dfe.iterrows():
#     plt.plot(featn,row['score_mean'], marker='o',label=row['trial'])
# #     plt.errorbar(featn,grid_score_mean[i],grid_score_std[i],label=f'trial-{i}')
#     plt.ylim(-2.1,-1.6)
#     plt.xlabel('Number of Features')
#     plt.ylabel('Cross-Validation Negative Mean Squared Error')
#     plt.title(f'Scree Plot')
#     plt.legend()
#     plt.show()
# dfe
# dfe['score_mean'][5]
# dfe['score_mean'][5]
# dfe
# dfe = dfe.drop(5)
# dfe
# dfe = dfe.drop(5)
# dfe
# mean = []
# for column in dfe.columns.values.tolist():
#     temp = []
#     for index, row in dfe.iterrows():
#         temp.append(row[column])
#
#     temp = np.array(temp)
#     mean.append(np.mean(temp))
# mean
# mean.append(np.nan)
# mean
# mean.append('trial-mean')
# mean
# dfe.loc[len(dfe)] = mean
# dfe
# mean = []
# for column in dfe.columns.values.tolist():
#     temp = []
#     for index, row in dfe.iterrows():
#         temp.append(row[column])
#
#     temp = np.array(temp)
#     mean.append(np.mean(temp),axis=0)
# dfe = dfe.drop(5)
# dfe
# mean = []
# for column in dfe.columns.values.tolist():
#     temp = []
#     for index, row in dfe.iterrows():
#         temp.append(row[column])
#
#     temp = np.array(temp)
#     mean.append(np.mean(temp),axis=0)
# mean = []
# for column in dfe.columns.values.tolist():
#     temp = []
#     for index, row in dfe.iterrows():
#         temp.append(row[column])
#     print(column,temp)
#     temp = np.array(temp)
#     mean.append(np.mean(temp),axis=0)
# mean = []
# for column in dfe.columns.values.tolist():
#     temp = []
#     for index, row in dfe.iterrows():
#         temp.append(row[column])
#     print(column,temp)
#     temp = np.array(temp)
#     mean.append(np.mean(temp,axis=0))
# mean = []
# for column in dfe.columns.values.tolist():
#     temp = []
#     for index, row in dfe.iterrows():
#         temp.append(row[column])
# #     print(column,temp)
#     temp = np.array(temp)
#     mean.append(np.mean(temp,axis=0))
# mean.append(np.nan,'trial-mean')
# mean
# mean.append(np.nan)
# mean.append('trial-mean')
# mean
# dfe.loc[len(dfe)] = mean
# dfe
# # mean = []
# # for column in dfe.columns.values.tolist():
# #     temp = []
# #     for index, row in dfe.iterrows():
# #         temp.append(row[column])
# # #     print(column,temp)
# #     temp = np.array(temp)
# #     mean.append(np.mean(temp,axis=0))
# featn = np.arange(782,10,-20)
# featn = featn[::-1]
#
# for index, row in dfe.iterrows():
#     plt.plot(featn,row['score_mean'], marker='o',label=row['trial'])
# #     plt.errorbar(featn,grid_score_mean[i],grid_score_std[i],label=f'trial-{i}')
#     plt.ylim(-2.1,-1.6)
#     plt.xlabel('Number of Features')
#     plt.ylabel('Cross-Validation Negative Mean Squared Error')
#     plt.title(f'Scree Plot')
#     plt.legend()
#     plt.show()
# dfe.loc[5,'score_mean']
# np.argmax(dfe.loc[5,'score_mean'])
# featn[np.argmax(dfe.loc[5,'score_mean'])]
# featn = np.arange(782,10,-20)
# featn = featn[::-1]
#
# for index, row in dfe.iterrows():
#     plt.plot(featn,row['score_mean'], marker='o',label=row['trial'])
# #     plt.errorbar(featn,grid_score_mean[i],grid_score_std[i],label=f'trial-{i}')
# #     plt.ylim(-2.1,-1.6)
#     plt.xlabel('Number of Features')
#     plt.ylabel('Cross-Validation Negative Mean Squared Error')
#     plt.title(f'Scree Plot')
#     plt.legend()
#     plt.show()
# dfe.to_csv('/mnt/inca/soc_eu_model/feature_selection/evaluation_matrix_log.csv')
# len(dfe.loc[5,'score_mean'])
# # warnings.filterwarnings(action='ignore')
#
# # grid_score_mean = []
# # grid_score_std = []
# # opti_feat_num = []
# # grid_feat_import = []
# # grid_feat = []
# # for i in [0,1,2,3,4]:
# #     rfecv = RFECV(estimator=RandomForestRegressor(200, n_jobs=60, random_state=i), cv=cv, step=20,
# #                   min_features_to_select=30, n_jobs=1, scoring='neg_mean_squared_error', verbose=1)
# #     rfecv.fit(df_slc[feat_cols], df_slc[tgt_col].values, groups=groups)
#
# #     grid_score_mean += [rfecv.cv_results_['mean_test_score']]
# #     grid_score_std += [rfecv.cv_results_["std_test_score"]]
# #     opti_feat_num.append(rfecv.n_features_)
# #     grid_feat_import.append(rfecv.estimator_.feature_importances_)
#
# #     dfe.loc[len(dfe)]=[rfecv.cv_results_['mean_test_score'],rfecv.cv_results_["std_test_score"],rfecv.n_features_,rfecv.estimator_.feature_importances_]
# #     dfe.to_csv('/mnt/inca/soc_eu_model/feature_selection/evaluation_matrix_log.csv')
#
# #     selected_feature_indices = np.where(rfecv.support_)[0]
# #     selected_features = [feat_cols[i] for i in selected_feature_indices]
# #     grid_feat.append(selected_features)
# num_feat = featn[np.argmax(dfe.loc[5,'score_mean'])]
# tgt_col
# cv
# groups
# rfe = RFE(estimator=RandomForestRegressor(200, n_jobs=60, random_state=0), step=20, n_features_to_select=num_feat, verbose=1)
# rfe.fit(df_slc[feat_cols], df_slc[tgt_col].values, groups=groups)
# import numpy as np
# import matplotlib.pyplot as plt
# import multiprocess as mp
# import glob
# import time
# from tqdm import tqdm
# import os
# import sys
# import pandas as pd
# from eumap.misc import find_files
# from eumap.raster import read_rasters, save_rasters
# from eumap.mapper import SpaceOverlay
# import geopandas as gpd
# from pathlib import Path
# import rasterio
# import pyproj
# from shapely.geometry import Point
# from eumap.mapper import LandMapper
#
# import warnings
#
# import matplotlib
# import matplotlib.pyplot as plt
#
# from sklearn.experimental import enable_halving_search_cv
# from sklearn.model_selection import train_test_split, cross_val_score, HalvingGridSearchCV, KFold, GroupKFold
# from sklearn.metrics import mean_squared_error, r2_score
# from sklearn.feature_selection import RFECV, RFE
# from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, StackingRegressor
# from sklearn.linear_model import Ridge, LinearRegression
# from sklearn.pipeline import Pipeline
# from sklearn.neural_network import MLPRegressor
# from sklearn.ensemble import StackingRegressor
#
# import joblib
# import pickle
# rfe = RFE(estimator=RandomForestRegressor(200, n_jobs=60, random_state=0), step=20, n_features_to_select=num_feat, verbose=1)
# rfe.fit(df_slc[feat_cols], df_slc[tgt_col].values, groups=groups)
# rfe = RFE(estimator=RandomForestRegressor(200, n_jobs=60, random_state=0), step=20, n_features_to_select=num_feat, verbose=1)
# rfe.fit(df_slc[feat_cols], df_slc[tgt_col].values)
# result = list(np.array(feat_cols)[rfe.support_])
# result
# omit = list(np.array(feat_cols)[~rfe.support_])
# omit
# result
# %history
